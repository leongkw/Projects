# %%
import pandas as pd

# %%
stats = pd.read_csv('stats_1.2.csv')

# %%
stats.drop(labels='Unnamed: 0', axis=1, inplace=True)

# %%
stats.columns
# Out:
# Index(['Year', 'Player', 'Pos', 'Age', 'TmWin', 'Tm', 'G', 'GS', 'MP', 'PER',
#        'TS%', '3PAr', 'FTr', 'ORB%', 'DRB%', 'TRB%', 'AST%', 'STL%', 'BLK%',
#        'TOV%', 'USG%', 'OWS', 'DWS', 'WS', 'WS/48', 'OBPM', 'DBPM', 'BPM',
#        'VORP', 'FG/G', 'FGA/G', 'FG%', '3P/G', '3PA/G', '3P%', '2P/G', '2PA/G',
#        '2P%', 'eFG%', 'FT/G', 'FTA/G', 'FT%', 'ORB/G', 'DRB/G', 'TRB/G',
#        'AST/G', 'STL/G', 'BLK/G', 'TOV/G', 'PF/G', 'PPG'],
#       dtype='object')

# %%
stats.drop(labels='TmWin', axis=1, inplace=True)

# %%
stats.head()
# Out:
#    Year                Player   Pos  Age   Tm   G  GS    MP   PER    TS%  \
# 0  1978       Zaid Abdul-Aziz  PF-C   31  TOT  16 NaN   158  11.4  0.449
# 1  1978       Zaid Abdul-Aziz     C   31  BOS   2 NaN    24  11.5  0.279
# 2  1978       Zaid Abdul-Aziz    PF   31  HOU  14 NaN   134  11.4  0.493
# 3  1978  Kareem Abdul-Jabbar*     C   30  LAL  62 NaN  2265  29.2  0.589
# 4  1978         Tom Abernethy    SF   23  LAL  73 NaN  1317  15.6  0.544
#
#    ...      FT%  ORB/G  DRB/G  TRB/G  AST/G  STL/G  BLK/G  TOV/G  PF/G    PPG
# 0  ...    0.739   1.19   1.94   3.13   0.63   0.19   0.19   0.88  1.81   3.94
# 1  ...    0.667   3.00   4.50   7.50   1.50   0.50   0.50   1.50  2.00   4.00
# 2  ...    0.750   0.93   1.57   2.50   0.50   0.14   0.14   0.79  1.79   3.93
# 3  ...    0.783   3.00   9.92  12.92   4.34   1.66   2.98   3.35  2.94  25.81
# 4  ...    0.820   1.44   2.19   3.63   1.38   0.75   0.30   0.68  1.67   6.75
#
# [5 rows x 50 columns]

# %%
stats['Tm'].unique()
# Done-list:
# ATL, BOS, HOU, LAL, PHO, CHI, IND, DET, GSW, NYK, MIL, PHI, CLE, SAS
# POR, DEN, UTA, DAL, LAC, SAC, MIA, ORL, MIN, TOR, WAS, MEM, NOH, CHA
# NOK, OKC, BRK, NOP, CHO, TOT*, KCK, NJN, BUF, NOJ, WSB, SEA, SDC, CHH, VAN

# Not Done:
# TOT, KCK, NJN, BUF, NOJ, WSB, SEA, SDC, CHH, VAN

# Need to remove TOT column since we're using groupby
# Out:
# array(['TOT', 'BOS', 'HOU', 'LAL', 'PHO', 'KCK', 'CHI', 'NJN', 'BUF',
#        'NOJ', 'WSB', 'IND', 'DET', 'GSW', 'NYK', 'ATL', 'MIL', 'PHI',
#        'CLE', 'SAS', 'SEA', 'POR', 'DEN', 'SDC', 'UTA', 'DAL', 'LAC',
#        'SAC', 'CHH', 'MIA', 'ORL', 'MIN', 'VAN', 'TOR', 'WAS', 'MEM',
#        'NOH', 'CHA', 'NOK', 'OKC', 'BRK', 'NOP', 'CHO'], dtype=object)

# %%
stats.shape
# Out:
# (21008, 50)

# %%
TmWin = pd.Series([])

for i in range(len(stats)):
    # For the Atlanta Hawks
    if stats['Tm'][i] == 'ATL' and stats['Year'][i] == 1978:
        TmWin[i] = 41
    elif stats['Tm'][i] == 'ATL' and stats['Year'][i] == 1979:
        TmWin[i] = 46
    elif stats['Tm'][i] == 'ATL' and stats['Year'][i] == 1980:
        TmWin[i] = 50
    elif stats['Tm'][i] == 'ATL' and stats['Year'][i] == 1981:
        TmWin[i] = 31
    elif stats['Tm'][i] == 'ATL' and stats['Year'][i] == 1982:
        TmWin[i] = 42
    elif stats['Tm'][i] == 'ATL' and stats['Year'][i] == 1983:
        TmWin[i] = 43
    elif stats['Tm'][i] == 'ATL' and stats['Year'][i] == 1984:
        TmWin[i] = 40
    elif stats['Tm'][i] == 'ATL' and stats['Year'][i] == 1985:
        TmWin[i] = 34
    elif stats['Tm'][i] == 'ATL' and stats['Year'][i] == 1986:
        TmWin[i] = 50
    elif stats['Tm'][i] == 'ATL' and stats['Year'][i] == 1987:
        TmWin[i] = 57
    elif stats['Tm'][i] == 'ATL' and stats['Year'][i] == 1988:
        TmWin[i] = 50
    elif stats['Tm'][i] == 'ATL' and stats['Year'][i] == 1989:
        TmWin[i] = 52
    elif stats['Tm'][i] == 'ATL' and stats['Year'][i] == 1990:
        TmWin[i] = 41
    elif stats['Tm'][i] == 'ATL' and stats['Year'][i] == 1991:
        TmWin[i] = 43
    elif stats['Tm'][i] == 'ATL' and stats['Year'][i] == 1992:
        TmWin[i] = 38
    elif stats['Tm'][i] == 'ATL' and stats['Year'][i] == 1993:
        TmWin[i] = 43
    elif stats['Tm'][i] == 'ATL' and stats['Year'][i] == 1994:
        TmWin[i] = 57
    elif stats['Tm'][i] == 'ATL' and stats['Year'][i] == 1995:
        TmWin[i] = 42
    elif stats['Tm'][i] == 'ATL' and stats['Year'][i] == 1996:
        TmWin[i] = 46
    elif stats['Tm'][i] == 'ATL' and stats['Year'][i] == 1997:
        TmWin[i] = 56
    elif stats['Tm'][i] == 'ATL' and stats['Year'][i] == 1998:
        TmWin[i] = 50
    elif stats['Tm'][i] == 'ATL' and stats['Year'][i] == 1999:
        TmWin[i] = 31
    elif stats['Tm'][i] == 'ATL' and stats['Year'][i] == 2000:
        TmWin[i] = 28
    elif stats['Tm'][i] == 'ATL' and stats['Year'][i] == 2001:
        TmWin[i] = 25
    elif stats['Tm'][i] == 'ATL' and stats['Year'][i] == 2002:
        TmWin[i] = 33
    elif stats['Tm'][i] == 'ATL' and stats['Year'][i] == 2003:
        TmWin[i] = 35
    elif stats['Tm'][i] == 'ATL' and stats['Year'][i] == 2004:
        TmWin[i] = 28
    elif stats['Tm'][i] == 'ATL' and stats['Year'][i] == 2005:
        TmWin[i] = 13
    elif stats['Tm'][i] == 'ATL' and stats['Year'][i] == 2006:
        TmWin[i] = 26
    elif stats['Tm'][i] == 'ATL' and stats['Year'][i] == 2007:
        TmWin[i] = 30
    elif stats['Tm'][i] == 'ATL' and stats['Year'][i] == 2008:
        TmWin[i] = 37
    elif stats['Tm'][i] == 'ATL' and stats['Year'][i] == 2009:
        TmWin[i] = 47
    elif stats['Tm'][i] == 'ATL' and stats['Year'][i] == 2010:
        TmWin[i] = 53
    elif stats['Tm'][i] == 'ATL' and stats['Year'][i] == 2011:
        TmWin[i] = 44
    elif stats['Tm'][i] == 'ATL' and stats['Year'][i] == 2012:
        TmWin[i] = 40
    elif stats['Tm'][i] == 'ATL' and stats['Year'][i] == 2013:
        TmWin[i] = 44
    elif stats['Tm'][i] == 'ATL' and stats['Year'][i] == 2014:
        TmWin[i] = 38
    elif stats['Tm'][i] == 'ATL' and stats['Year'][i] == 2015:
        TmWin[i] = 60
    elif stats['Tm'][i] == 'ATL' and stats['Year'][i] == 2016:
        TmWin[i] = 48
    elif stats['Tm'][i] == 'ATL' and stats['Year'][i] == 2017:
        TmWin[i] = 43
    elif stats['Tm'][i] == 'ATL' and stats['Year'][i] == 2018:
        TmWin[i] = 24
    elif stats['Tm'][i] == 'ATL' and stats['Year'][i] == 2019:
        TmWin[i] = 43
    
    # For boston celtics
    elif stats['Tm'][i] == 'BOS' and stats['Year'][i] == 1978:
        TmWin[i] = 32
    elif stats['Tm'][i] == 'BOS' and stats['Year'][i] == 1979:
        TmWin[i] = 29
    elif stats['Tm'][i] == 'BOS' and stats['Year'][i] == 1980:
        TmWin[i] = 61
    elif stats['Tm'][i] == 'BOS' and stats['Year'][i] == 1981:
        TmWin[i] = 62
    elif stats['Tm'][i] == 'BOS' and stats['Year'][i] == 1982:
        TmWin[i] = 63
    elif stats['Tm'][i] == 'BOS' and stats['Year'][i] == 1983:
        TmWin[i] = 56
    elif stats['Tm'][i] == 'BOS' and stats['Year'][i] == 1984:
        TmWin[i] = 62
    elif stats['Tm'][i] == 'BOS' and stats['Year'][i] == 1985:
        TmWin[i] = 63
    elif stats['Tm'][i] == 'BOS' and stats['Year'][i] == 1986:
        TmWin[i] = 67
    elif stats['Tm'][i] == 'BOS' and stats['Year'][i] == 1987:
        TmWin[i] = 59
    elif stats['Tm'][i] == 'BOS' and stats['Year'][i] == 1988:
        TmWin[i] = 57
    elif stats['Tm'][i] == 'BOS' and stats['Year'][i] == 1989:
        TmWin[i] = 42
    elif stats['Tm'][i] == 'BOS' and stats['Year'][i] == 1990:
        TmWin[i] = 52
    elif stats['Tm'][i] == 'BOS' and stats['Year'][i] == 1991:
        TmWin[i] = 56
    elif stats['Tm'][i] == 'BOS' and stats['Year'][i] == 1992:
        TmWin[i] = 51
    elif stats['Tm'][i] == 'BOS' and stats['Year'][i] == 1993:
        TmWin[i] = 48
    elif stats['Tm'][i] == 'BOS' and stats['Year'][i] == 1994:
        TmWin[i] = 32
    elif stats['Tm'][i] == 'BOS' and stats['Year'][i] == 1995:
        TmWin[i] = 35
    elif stats['Tm'][i] == 'BOS' and stats['Year'][i] == 1996:
        TmWin[i] = 33
    elif stats['Tm'][i] == 'BOS' and stats['Year'][i] == 1997:
        TmWin[i] = 15
    elif stats['Tm'][i] == 'BOS' and stats['Year'][i] == 1998:
        TmWin[i] = 36
    elif stats['Tm'][i] == 'BOS' and stats['Year'][i] == 1999:
        TmWin[i] = 19
    elif stats['Tm'][i] == 'BOS' and stats['Year'][i] == 2000:
        TmWin[i] = 35
    elif stats['Tm'][i] == 'BOS' and stats['Year'][i] == 2001:
        TmWin[i] = 36
    elif stats['Tm'][i] == 'BOS' and stats['Year'][i] == 2002:
        TmWin[i] = 49
    elif stats['Tm'][i] == 'BOS' and stats['Year'][i] == 2003:
        TmWin[i] = 44
    elif stats['Tm'][i] == 'BOS' and stats['Year'][i] == 2004:
        TmWin[i] = 36
    elif stats['Tm'][i] == 'BOS' and stats['Year'][i] == 2005:
        TmWin[i] = 45
    elif stats['Tm'][i] == 'BOS' and stats['Year'][i] == 2006:
        TmWin[i] = 33
    elif stats['Tm'][i] == 'BOS' and stats['Year'][i] == 2007:
        TmWin[i] = 24
    elif stats['Tm'][i] == 'BOS' and stats['Year'][i] == 2008:
        TmWin[i] = 66
    elif stats['Tm'][i] == 'BOS' and stats['Year'][i] == 2009:
        TmWin[i] = 62
    elif stats['Tm'][i] == 'BOS' and stats['Year'][i] == 2010:
        TmWin[i] = 50
    elif stats['Tm'][i] == 'BOS' and stats['Year'][i] == 2011:
        TmWin[i] = 56
    elif stats['Tm'][i] == 'BOS' and stats['Year'][i] == 2012:
        TmWin[i] = 39
    elif stats['Tm'][i] == 'BOS' and stats['Year'][i] == 2013:
        TmWin[i] = 41
    elif stats['Tm'][i] == 'BOS' and stats['Year'][i] == 2014:
        TmWin[i] = 25
    elif stats['Tm'][i] == 'BOS' and stats['Year'][i] == 2015:
        TmWin[i] = 40
    elif stats['Tm'][i] == 'BOS' and stats['Year'][i] == 2016:
        TmWin[i] = 48
    elif stats['Tm'][i] == 'BOS' and stats['Year'][i] == 2017:
        TmWin[i] = 53
    elif stats['Tm'][i] == 'BOS' and stats['Year'][i] == 2018:
        TmWin[i] = 55
    elif stats['Tm'][i] == 'BOS' and stats['Year'][i] == 2019:
        TmWin[i] = 49
    
    # For Houston Rockets
    elif stats['Tm'][i] == 'HOU' and stats['Year'][i] == 1978:
        TmWin[i] = 28
    elif stats['Tm'][i] == 'HOU' and stats['Year'][i] == 1979:
        TmWin[i] = 47
    elif stats['Tm'][i] == 'HOU' and stats['Year'][i] == 1980:
        TmWin[i] = 41
    elif stats['Tm'][i] == 'HOU' and stats['Year'][i] == 1981:
        TmWin[i] = 40
    elif stats['Tm'][i] == 'HOU' and stats['Year'][i] == 1982:
        TmWin[i] = 46
    elif stats['Tm'][i] == 'HOU' and stats['Year'][i] == 1983:
        TmWin[i] = 14
    elif stats['Tm'][i] == 'HOU' and stats['Year'][i] == 1984:
        TmWin[i] = 29
    elif stats['Tm'][i] == 'HOU' and stats['Year'][i] == 1985:
        TmWin[i] = 48
    elif stats['Tm'][i] == 'HOU' and stats['Year'][i] == 1986:
        TmWin[i] = 51
    elif stats['Tm'][i] == 'HOU' and stats['Year'][i] == 1987:
        TmWin[i] = 42
    elif stats['Tm'][i] == 'HOU' and stats['Year'][i] == 1988:
        TmWin[i] = 46
    elif stats['Tm'][i] == 'HOU' and stats['Year'][i] == 1989:
        TmWin[i] = 45
    elif stats['Tm'][i] == 'HOU' and stats['Year'][i] == 1990:
        TmWin[i] = 41
    elif stats['Tm'][i] == 'HOU' and stats['Year'][i] == 1991:
        TmWin[i] = 52
    elif stats['Tm'][i] == 'HOU' and stats['Year'][i] == 1992:
        TmWin[i] = 42
    elif stats['Tm'][i] == 'HOU' and stats['Year'][i] == 1993:
        TmWin[i] = 55
    elif stats['Tm'][i] == 'HOU' and stats['Year'][i] == 1994:
        TmWin[i] = 58
    elif stats['Tm'][i] == 'HOU' and stats['Year'][i] == 1995:
        TmWin[i] = 47
    elif stats['Tm'][i] == 'HOU' and stats['Year'][i] == 1996:
        TmWin[i] = 48
    elif stats['Tm'][i] == 'HOU' and stats['Year'][i] == 1997:
        TmWin[i] = 57
    elif stats['Tm'][i] == 'HOU' and stats['Year'][i] == 1998:
        TmWin[i] = 41
    elif stats['Tm'][i] == 'HOU' and stats['Year'][i] == 1999:
        TmWin[i] = 31
    elif stats['Tm'][i] == 'HOU' and stats['Year'][i] == 2000:
        TmWin[i] = 34
    elif stats['Tm'][i] == 'HOU' and stats['Year'][i] == 2001:
        TmWin[i] = 45
    elif stats['Tm'][i] == 'HOU' and stats['Year'][i] == 2002:
        TmWin[i] = 28
    elif stats['Tm'][i] == 'HOU' and stats['Year'][i] == 2003:
        TmWin[i] = 43
    elif stats['Tm'][i] == 'HOU' and stats['Year'][i] == 2004:
        TmWin[i] = 45
    elif stats['Tm'][i] == 'HOU' and stats['Year'][i] == 2005:
        TmWin[i] = 51
    elif stats['Tm'][i] == 'HOU' and stats['Year'][i] == 2006:
        TmWin[i] = 34
    elif stats['Tm'][i] == 'HOU' and stats['Year'][i] == 2007:
        TmWin[i] = 52
    elif stats['Tm'][i] == 'HOU' and stats['Year'][i] == 2008:
        TmWin[i] = 55
    elif stats['Tm'][i] == 'HOU' and stats['Year'][i] == 2009:
        TmWin[i] = 53
    elif stats['Tm'][i] == 'HOU' and stats['Year'][i] == 2010:
        TmWin[i] = 42
    elif stats['Tm'][i] == 'HOU' and stats['Year'][i] == 2011:
        TmWin[i] = 43
    elif stats['Tm'][i] == 'HOU' and stats['Year'][i] == 2012:
        TmWin[i] = 34
    elif stats['Tm'][i] == 'HOU' and stats['Year'][i] == 2013:
        TmWin[i] = 45
    elif stats['Tm'][i] == 'HOU' and stats['Year'][i] == 2014:
        TmWin[i] = 54
    elif stats['Tm'][i] == 'HOU' and stats['Year'][i] == 2015:
        TmWin[i] = 56
    elif stats['Tm'][i] == 'HOU' and stats['Year'][i] == 2016:
        TmWin[i] = 41
    elif stats['Tm'][i] == 'HOU' and stats['Year'][i] == 2017:
        TmWin[i] = 55
    elif stats['Tm'][i] == 'HOU' and stats['Year'][i] == 2018:
        TmWin[i] = 65
    elif stats['Tm'][i] == 'HOU' and stats['Year'][i] == 2019:
        TmWin[i] = 53
    
    # For Lakers
    elif stats['Tm'][i] == 'LAL' and stats['Year'][i] == 1978:
        TmWin[i] = 45
    elif stats['Tm'][i] == 'LAL' and stats['Year'][i] == 1979:
        TmWin[i] = 47
    elif stats['Tm'][i] == 'LAL' and stats['Year'][i] == 1980:
        TmWin[i] = 60
    elif stats['Tm'][i] == 'LAL' and stats['Year'][i] == 1981:
        TmWin[i] = 54
    elif stats['Tm'][i] == 'LAL' and stats['Year'][i] == 1982:
        TmWin[i] = 57
    elif stats['Tm'][i] == 'LAL' and stats['Year'][i] == 1983:
        TmWin[i] = 58
    elif stats['Tm'][i] == 'LAL' and stats['Year'][i] == 1984:
        TmWin[i] = 54
    elif stats['Tm'][i] == 'LAL' and stats['Year'][i] == 1985:
        TmWin[i] = 62
    elif stats['Tm'][i] == 'LAL' and stats['Year'][i] == 1986:
        TmWin[i] = 62
    elif stats['Tm'][i] == 'LAL' and stats['Year'][i] == 1987:
        TmWin[i] = 65
    elif stats['Tm'][i] == 'LAL' and stats['Year'][i] == 1988:
        TmWin[i] = 62
    elif stats['Tm'][i] == 'LAL' and stats['Year'][i] == 1989:
        TmWin[i] = 57
    elif stats['Tm'][i] == 'LAL' and stats['Year'][i] == 1990:
        TmWin[i] = 63
    elif stats['Tm'][i] == 'LAL' and stats['Year'][i] == 1991:
        TmWin[i] = 58
    elif stats['Tm'][i] == 'LAL' and stats['Year'][i] == 1992:
        TmWin[i] = 43
    elif stats['Tm'][i] == 'LAL' and stats['Year'][i] == 1993:
        TmWin[i] = 39
    elif stats['Tm'][i] == 'LAL' and stats['Year'][i] == 1994:
        TmWin[i] = 33
    elif stats['Tm'][i] == 'LAL' and stats['Year'][i] == 1995:
        TmWin[i] = 48
    elif stats['Tm'][i] == 'LAL' and stats['Year'][i] == 1996:
        TmWin[i] = 53
    elif stats['Tm'][i] == 'LAL' and stats['Year'][i] == 1997:
        TmWin[i] = 56
    elif stats['Tm'][i] == 'LAL' and stats['Year'][i] == 1998:
        TmWin[i] = 61
    elif stats['Tm'][i] == 'LAL' and stats['Year'][i] == 1999:
        TmWin[i] = 31
    elif stats['Tm'][i] == 'LAL' and stats['Year'][i] == 2000:
        TmWin[i] = 67
    elif stats['Tm'][i] == 'LAL' and stats['Year'][i] == 2001:
        TmWin[i] = 56
    elif stats['Tm'][i] == 'LAL' and stats['Year'][i] == 2002:
        TmWin[i] = 58
    elif stats['Tm'][i] == 'LAL' and stats['Year'][i] == 2003:
        TmWin[i] = 50
    elif stats['Tm'][i] == 'LAL' and stats['Year'][i] == 2004:
        TmWin[i] = 56
    elif stats['Tm'][i] == 'LAL' and stats['Year'][i] == 2005:
        TmWin[i] = 34
    elif stats['Tm'][i] == 'LAL' and stats['Year'][i] == 2006:
        TmWin[i] = 45
    elif stats['Tm'][i] == 'LAL' and stats['Year'][i] == 2007:
        TmWin[i] = 42
    elif stats['Tm'][i] == 'LAL' and stats['Year'][i] == 2008:
        TmWin[i] = 57
    elif stats['Tm'][i] == 'LAL' and stats['Year'][i] == 2009:
        TmWin[i] = 65
    elif stats['Tm'][i] == 'LAL' and stats['Year'][i] == 2010:
        TmWin[i] = 57
    elif stats['Tm'][i] == 'LAL' and stats['Year'][i] == 2011:
        TmWin[i] = 57
    elif stats['Tm'][i] == 'LAL' and stats['Year'][i] == 2012:
        TmWin[i] = 41
    elif stats['Tm'][i] == 'LAL' and stats['Year'][i] == 2013:
        TmWin[i] = 45
    elif stats['Tm'][i] == 'LAL' and stats['Year'][i] == 2014:
        TmWin[i] = 27
    elif stats['Tm'][i] == 'LAL' and stats['Year'][i] == 2015:
        TmWin[i] = 21
    elif stats['Tm'][i] == 'LAL' and stats['Year'][i] == 2016:
        TmWin[i] = 17
    elif stats['Tm'][i] == 'LAL' and stats['Year'][i] == 2017:
        TmWin[i] = 26
    elif stats['Tm'][i] == 'LAL' and stats['Year'][i] == 2018:
        TmWin[i] = 35
    elif stats['Tm'][i] == 'LAL' and stats['Year'][i] == 2019:
        TmWin[i] = 37
    
    # For pheonix suns
    elif stats['Tm'][i] == 'PHO' and stats['Year'][i] == 1978:
        TmWin[i] = 49
    elif stats['Tm'][i] == 'PHO' and stats['Year'][i] == 1979:
        TmWin[i] = 50
    elif stats['Tm'][i] == 'PHO' and stats['Year'][i] == 1980:
        TmWin[i] = 55
    elif stats['Tm'][i] == 'PHO' and stats['Year'][i] == 1981:
        TmWin[i] = 57
    elif stats['Tm'][i] == 'PHO' and stats['Year'][i] == 1982:
        TmWin[i] = 46
    elif stats['Tm'][i] == 'PHO' and stats['Year'][i] == 1983:
        TmWin[i] = 53
    elif stats['Tm'][i] == 'PHO' and stats['Year'][i] == 1984:
        TmWin[i] = 41
    elif stats['Tm'][i] == 'PHO' and stats['Year'][i] == 1985:
        TmWin[i] = 36
    elif stats['Tm'][i] == 'PHO' and stats['Year'][i] == 1986:
        TmWin[i] = 32
    elif stats['Tm'][i] == 'PHO' and stats['Year'][i] == 1987:
        TmWin[i] = 36
    elif stats['Tm'][i] == 'PHO' and stats['Year'][i] == 1988:
        TmWin[i] = 28
    elif stats['Tm'][i] == 'PHO' and stats['Year'][i] == 1989:
        TmWin[i] = 55
    elif stats['Tm'][i] == 'PHO' and stats['Year'][i] == 1990:
        TmWin[i] = 54
    elif stats['Tm'][i] == 'PHO' and stats['Year'][i] == 1991:
        TmWin[i] = 55
    elif stats['Tm'][i] == 'PHO' and stats['Year'][i] == 1992:
        TmWin[i] = 53
    elif stats['Tm'][i] == 'PHO' and stats['Year'][i] == 1993:
        TmWin[i] = 62
    elif stats['Tm'][i] == 'PHO' and stats['Year'][i] == 1994:
        TmWin[i] = 56
    elif stats['Tm'][i] == 'PHO' and stats['Year'][i] == 1995:
        TmWin[i] = 59
    elif stats['Tm'][i] == 'PHO' and stats['Year'][i] == 1996:
        TmWin[i] = 41
    elif stats['Tm'][i] == 'PHO' and stats['Year'][i] == 1997:
        TmWin[i] = 40
    elif stats['Tm'][i] == 'PHO' and stats['Year'][i] == 1998:
        TmWin[i] = 56
    elif stats['Tm'][i] == 'PHO' and stats['Year'][i] == 1999:
        TmWin[i] = 27
    elif stats['Tm'][i] == 'PHO' and stats['Year'][i] == 2000:
        TmWin[i] = 53
    elif stats['Tm'][i] == 'PHO' and stats['Year'][i] == 2001:
        TmWin[i] = 51
    elif stats['Tm'][i] == 'PHO' and stats['Year'][i] == 2002:
        TmWin[i] = 36
    elif stats['Tm'][i] == 'PHO' and stats['Year'][i] == 2003:
        TmWin[i] = 44
    elif stats['Tm'][i] == 'PHO' and stats['Year'][i] == 2004:
        TmWin[i] = 29
    elif stats['Tm'][i] == 'PHO' and stats['Year'][i] == 2005:
        TmWin[i] = 62
    elif stats['Tm'][i] == 'PHO' and stats['Year'][i] == 2006:
        TmWin[i] = 54
    elif stats['Tm'][i] == 'PHO' and stats['Year'][i] == 2007:
        TmWin[i] = 61
    elif stats['Tm'][i] == 'PHO' and stats['Year'][i] == 2008:
        TmWin[i] = 55
    elif stats['Tm'][i] == 'PHO' and stats['Year'][i] == 2009:
        TmWin[i] = 46
    elif stats['Tm'][i] == 'PHO' and stats['Year'][i] == 2010:
        TmWin[i] = 54
    elif stats['Tm'][i] == 'PHO' and stats['Year'][i] == 2011:
        TmWin[i] = 40
    elif stats['Tm'][i] == 'PHO' and stats['Year'][i] == 2012:
        TmWin[i] = 33
    elif stats['Tm'][i] == 'PHO' and stats['Year'][i] == 2013:
        TmWin[i] = 25
    elif stats['Tm'][i] == 'PHO' and stats['Year'][i] == 2014:
        TmWin[i] = 48
    elif stats['Tm'][i] == 'PHO' and stats['Year'][i] == 2015:
        TmWin[i] = 39
    elif stats['Tm'][i] == 'PHO' and stats['Year'][i] == 2016:
        TmWin[i] = 23
    elif stats['Tm'][i] == 'PHO' and stats['Year'][i] == 2017:
        TmWin[i] = 24
    elif stats['Tm'][i] == 'PHO' and stats['Year'][i] == 2018:
        TmWin[i] = 21
    elif stats['Tm'][i] == 'PHO' and stats['Year'][i] == 2019:
        TmWin[i] = 19
    
    # For Chicago Bulls
    elif stats['Tm'][i] == 'CHI' and stats['Year'][i] == 1978:
        TmWin[i] = 40
    elif stats['Tm'][i] == 'CHI' and stats['Year'][i] == 1979:
        TmWin[i] = 31
    elif stats['Tm'][i] == 'CHI' and stats['Year'][i] == 1980:
        TmWin[i] = 30
    elif stats['Tm'][i] == 'CHI' and stats['Year'][i] == 1981:
        TmWin[i] = 45
    elif stats['Tm'][i] == 'CHI' and stats['Year'][i] == 1982:
        TmWin[i] = 34
    elif stats['Tm'][i] == 'CHI' and stats['Year'][i] == 1983:
        TmWin[i] = 28
    elif stats['Tm'][i] == 'CHI' and stats['Year'][i] == 1984:
        TmWin[i] = 27
    elif stats['Tm'][i] == 'CHI' and stats['Year'][i] == 1985:
        TmWin[i] = 38
    elif stats['Tm'][i] == 'CHI' and stats['Year'][i] == 1986:
        TmWin[i] = 30
    elif stats['Tm'][i] == 'CHI' and stats['Year'][i] == 1987:
        TmWin[i] = 40
    elif stats['Tm'][i] == 'CHI' and stats['Year'][i] == 1988:
        TmWin[i] = 50
    elif stats['Tm'][i] == 'CHI' and stats['Year'][i] == 1989:
        TmWin[i] = 47
    elif stats['Tm'][i] == 'CHI' and stats['Year'][i] == 1990:
        TmWin[i] = 55
    elif stats['Tm'][i] == 'CHI' and stats['Year'][i] == 1991:
        TmWin[i] = 61
    elif stats['Tm'][i] == 'CHI' and stats['Year'][i] == 1992:
        TmWin[i] = 67
    elif stats['Tm'][i] == 'CHI' and stats['Year'][i] == 1993:
        TmWin[i] = 57
    elif stats['Tm'][i] == 'CHI' and stats['Year'][i] == 1994:
        TmWin[i] = 55
    elif stats['Tm'][i] == 'CHI' and stats['Year'][i] == 1995:
        TmWin[i] = 47
    elif stats['Tm'][i] == 'CHI' and stats['Year'][i] == 1996:
        TmWin[i] = 72
    elif stats['Tm'][i] == 'CHI' and stats['Year'][i] == 1997:
        TmWin[i] = 69
    elif stats['Tm'][i] == 'CHI' and stats['Year'][i] == 1998:
        TmWin[i] = 62
    elif stats['Tm'][i] == 'CHI' and stats['Year'][i] == 1999:
        TmWin[i] = 13
    elif stats['Tm'][i] == 'CHI' and stats['Year'][i] == 2000:
        TmWin[i] = 17
    elif stats['Tm'][i] == 'CHI' and stats['Year'][i] == 2001:
        TmWin[i] = 15
    elif stats['Tm'][i] == 'CHI' and stats['Year'][i] == 2002:
        TmWin[i] = 21
    elif stats['Tm'][i] == 'CHI' and stats['Year'][i] == 2003:
        TmWin[i] = 30
    elif stats['Tm'][i] == 'CHI' and stats['Year'][i] == 2004:
        TmWin[i] = 23
    elif stats['Tm'][i] == 'CHI' and stats['Year'][i] == 2005:
        TmWin[i] = 47
    elif stats['Tm'][i] == 'CHI' and stats['Year'][i] == 2006:
        TmWin[i] = 41
    elif stats['Tm'][i] == 'CHI' and stats['Year'][i] == 2007:
        TmWin[i] = 49
    elif stats['Tm'][i] == 'CHI' and stats['Year'][i] == 2008:
        TmWin[i] = 33
    elif stats['Tm'][i] == 'CHI' and stats['Year'][i] == 2009:
        TmWin[i] = 41
    elif stats['Tm'][i] == 'CHI' and stats['Year'][i] == 2010:
        TmWin[i] = 41
    elif stats['Tm'][i] == 'CHI' and stats['Year'][i] == 2011:
        TmWin[i] = 62
    elif stats['Tm'][i] == 'CHI' and stats['Year'][i] == 2012:
        TmWin[i] = 50
    elif stats['Tm'][i] == 'CHI' and stats['Year'][i] == 2013:
        TmWin[i] = 45
    elif stats['Tm'][i] == 'CHI' and stats['Year'][i] == 2014:
        TmWin[i] = 48
    elif stats['Tm'][i] == 'CHI' and stats['Year'][i] == 2015:
        TmWin[i] = 50
    elif stats['Tm'][i] == 'CHI' and stats['Year'][i] == 2016:
        TmWin[i] = 42
    elif stats['Tm'][i] == 'CHI' and stats['Year'][i] == 2017:
        TmWin[i] = 41
    elif stats['Tm'][i] == 'CHI' and stats['Year'][i] == 2018:
        TmWin[i] = 27
    elif stats['Tm'][i] == 'CHI' and stats['Year'][i] == 2019:
        TmWin[i] = 22
    
    # For Indiana Pacers
    elif stats['Tm'][i] == 'IND' and stats['Year'][i] == 1978:
        TmWin[i] = 31
    elif stats['Tm'][i] == 'IND' and stats['Year'][i] == 1979:
        TmWin[i] = 38
    elif stats['Tm'][i] == 'IND' and stats['Year'][i] == 1980:
        TmWin[i] = 37
    elif stats['Tm'][i] == 'IND' and stats['Year'][i] == 1981:
        TmWin[i] = 44
    elif stats['Tm'][i] == 'IND' and stats['Year'][i] == 1982:
        TmWin[i] = 35
    elif stats['Tm'][i] == 'IND' and stats['Year'][i] == 1983:
        TmWin[i] = 20
    elif stats['Tm'][i] == 'IND' and stats['Year'][i] == 1984:
        TmWin[i] = 26
    elif stats['Tm'][i] == 'IND' and stats['Year'][i] == 1985:
        TmWin[i] = 22
    elif stats['Tm'][i] == 'IND' and stats['Year'][i] == 1986:
        TmWin[i] = 26
    elif stats['Tm'][i] == 'IND' and stats['Year'][i] == 1987:
        TmWin[i] = 41
    elif stats['Tm'][i] == 'IND' and stats['Year'][i] == 1988:
        TmWin[i] = 38
    elif stats['Tm'][i] == 'IND' and stats['Year'][i] == 1989:
        TmWin[i] = 28
    elif stats['Tm'][i] == 'IND' and stats['Year'][i] == 1990:
        TmWin[i] = 42
    elif stats['Tm'][i] == 'IND' and stats['Year'][i] == 1991:
        TmWin[i] = 41
    elif stats['Tm'][i] == 'IND' and stats['Year'][i] == 1992:
        TmWin[i] = 40
    elif stats['Tm'][i] == 'IND' and stats['Year'][i] == 1993:
        TmWin[i] = 41
    elif stats['Tm'][i] == 'IND' and stats['Year'][i] == 1994:
        TmWin[i] = 47
    elif stats['Tm'][i] == 'IND' and stats['Year'][i] == 1995:
        TmWin[i] = 52
    elif stats['Tm'][i] == 'IND' and stats['Year'][i] == 1996:
        TmWin[i] = 52
    elif stats['Tm'][i] == 'IND' and stats['Year'][i] == 1997:
        TmWin[i] = 39
    elif stats['Tm'][i] == 'IND' and stats['Year'][i] == 1998:
        TmWin[i] = 58
    elif stats['Tm'][i] == 'IND' and stats['Year'][i] == 1999:
        TmWin[i] = 33
    elif stats['Tm'][i] == 'IND' and stats['Year'][i] == 2000:
        TmWin[i] = 56
    elif stats['Tm'][i] == 'IND' and stats['Year'][i] == 2001:
        TmWin[i] = 41
    elif stats['Tm'][i] == 'IND' and stats['Year'][i] == 2002:
        TmWin[i] = 42
    elif stats['Tm'][i] == 'IND' and stats['Year'][i] == 2003:
        TmWin[i] = 48
    elif stats['Tm'][i] == 'IND' and stats['Year'][i] == 2004:
        TmWin[i] = 61
    elif stats['Tm'][i] == 'IND' and stats['Year'][i] == 2005:
        TmWin[i] = 44
    elif stats['Tm'][i] == 'IND' and stats['Year'][i] == 2006:
        TmWin[i] = 41
    elif stats['Tm'][i] == 'IND' and stats['Year'][i] == 2007:
        TmWin[i] = 35
    elif stats['Tm'][i] == 'IND' and stats['Year'][i] == 2008:
        TmWin[i] = 36
    elif stats['Tm'][i] == 'IND' and stats['Year'][i] == 2009:
        TmWin[i] = 36
    elif stats['Tm'][i] == 'IND' and stats['Year'][i] == 2010:
        TmWin[i] = 32
    elif stats['Tm'][i] == 'IND' and stats['Year'][i] == 2011:
        TmWin[i] = 37
    elif stats['Tm'][i] == 'IND' and stats['Year'][i] == 2012:
        TmWin[i] = 42
    elif stats['Tm'][i] == 'IND' and stats['Year'][i] == 2013:
        TmWin[i] = 49
    elif stats['Tm'][i] == 'IND' and stats['Year'][i] == 2014:
        TmWin[i] = 56
    elif stats['Tm'][i] == 'IND' and stats['Year'][i] == 2015:
        TmWin[i] = 38
    elif stats['Tm'][i] == 'IND' and stats['Year'][i] == 2016:
        TmWin[i] = 45
    elif stats['Tm'][i] == 'IND' and stats['Year'][i] == 2017:
        TmWin[i] = 42
    elif stats['Tm'][i] == 'IND' and stats['Year'][i] == 2018:
        TmWin[i] = 48
    elif stats['Tm'][i] == 'IND' and stats['Year'][i] == 2019:
        TmWin[i] = 48
    
    # For Detriot Pistons
    elif stats['Tm'][i] == 'DET' and stats['Year'][i] == 1978:
        TmWin[i] = 38
    elif stats['Tm'][i] == 'DET' and stats['Year'][i] == 1979:
        TmWin[i] = 30
    elif stats['Tm'][i] == 'DET' and stats['Year'][i] == 1980:
        TmWin[i] = 16
    elif stats['Tm'][i] == 'DET' and stats['Year'][i] == 1981:
        TmWin[i] = 21
    elif stats['Tm'][i] == 'DET' and stats['Year'][i] == 1982:
        TmWin[i] = 39
    elif stats['Tm'][i] == 'DET' and stats['Year'][i] == 1983:
        TmWin[i] = 37
    elif stats['Tm'][i] == 'DET' and stats['Year'][i] == 1984:
        TmWin[i] = 49
    elif stats['Tm'][i] == 'DET' and stats['Year'][i] == 1985:
        TmWin[i] = 46
    elif stats['Tm'][i] == 'DET' and stats['Year'][i] == 1986:
        TmWin[i] = 46
    elif stats['Tm'][i] == 'DET' and stats['Year'][i] == 1987:
        TmWin[i] = 52
    elif stats['Tm'][i] == 'DET' and stats['Year'][i] == 1988:
        TmWin[i] = 54
    elif stats['Tm'][i] == 'DET' and stats['Year'][i] == 1989:
        TmWin[i] = 63
    elif stats['Tm'][i] == 'DET' and stats['Year'][i] == 1990:
        TmWin[i] = 59
    elif stats['Tm'][i] == 'DET' and stats['Year'][i] == 1991:
        TmWin[i] = 50
    elif stats['Tm'][i] == 'DET' and stats['Year'][i] == 1992:
        TmWin[i] = 48
    elif stats['Tm'][i] == 'DET' and stats['Year'][i] == 1993:
        TmWin[i] = 40
    elif stats['Tm'][i] == 'DET' and stats['Year'][i] == 1994:
        TmWin[i] = 20
    elif stats['Tm'][i] == 'DET' and stats['Year'][i] == 1995:
        TmWin[i] = 28
    elif stats['Tm'][i] == 'DET' and stats['Year'][i] == 1996:
        TmWin[i] = 46
    elif stats['Tm'][i] == 'DET' and stats['Year'][i] == 1997:
        TmWin[i] = 54
    elif stats['Tm'][i] == 'DET' and stats['Year'][i] == 1998:
        TmWin[i] = 37
    elif stats['Tm'][i] == 'DET' and stats['Year'][i] == 1999:
        TmWin[i] = 29
    elif stats['Tm'][i] == 'DET' and stats['Year'][i] == 2000:
        TmWin[i] = 42
    elif stats['Tm'][i] == 'DET' and stats['Year'][i] == 2001:
        TmWin[i] = 32
    elif stats['Tm'][i] == 'DET' and stats['Year'][i] == 2002:
        TmWin[i] = 50
    elif stats['Tm'][i] == 'DET' and stats['Year'][i] == 2003:
        TmWin[i] = 50
    elif stats['Tm'][i] == 'DET' and stats['Year'][i] == 2004:
        TmWin[i] = 54
    elif stats['Tm'][i] == 'DET' and stats['Year'][i] == 2005:
        TmWin[i] = 54
    elif stats['Tm'][i] == 'DET' and stats['Year'][i] == 2006:
        TmWin[i] = 64
    elif stats['Tm'][i] == 'DET' and stats['Year'][i] == 2007:
        TmWin[i] = 53
    elif stats['Tm'][i] == 'DET' and stats['Year'][i] == 2008:
        TmWin[i] = 59
    elif stats['Tm'][i] == 'DET' and stats['Year'][i] == 2009:
        TmWin[i] = 39
    elif stats['Tm'][i] == 'DET' and stats['Year'][i] == 2010:
        TmWin[i] = 27
    elif stats['Tm'][i] == 'DET' and stats['Year'][i] == 2011:
        TmWin[i] = 30
    elif stats['Tm'][i] == 'DET' and stats['Year'][i] == 2012:
        TmWin[i] = 25
    elif stats['Tm'][i] == 'DET' and stats['Year'][i] == 2013:
        TmWin[i] = 29
    elif stats['Tm'][i] == 'DET' and stats['Year'][i] == 2014:
        TmWin[i] = 29
    elif stats['Tm'][i] == 'DET' and stats['Year'][i] == 2015:
        TmWin[i] = 32
    elif stats['Tm'][i] == 'DET' and stats['Year'][i] == 2016:
        TmWin[i] = 44
    elif stats['Tm'][i] == 'DET' and stats['Year'][i] == 2017:
        TmWin[i] = 37
    elif stats['Tm'][i] == 'DET' and stats['Year'][i] == 2018:
        TmWin[i] = 39
    elif stats['Tm'][i] == 'DET' and stats['Year'][i] == 2019:
        TmWin[i] = 41
    
    # For Warriors
    elif stats['Tm'][i] == 'GSW' and stats['Year'][i] == 1978:
        TmWin[i] = 43
    elif stats['Tm'][i] == 'GSW' and stats['Year'][i] == 1979:
        TmWin[i] = 38
    elif stats['Tm'][i] == 'GSW' and stats['Year'][i] == 1980:
        TmWin[i] = 24
    elif stats['Tm'][i] == 'GSW' and stats['Year'][i] == 1981:
        TmWin[i] = 39
    elif stats['Tm'][i] == 'GSW' and stats['Year'][i] == 1982:
        TmWin[i] = 45
    elif stats['Tm'][i] == 'GSW' and stats['Year'][i] == 1983:
        TmWin[i] = 30
    elif stats['Tm'][i] == 'GSW' and stats['Year'][i] == 1984:
        TmWin[i] = 37
    elif stats['Tm'][i] == 'GSW' and stats['Year'][i] == 1985:
        TmWin[i] = 22
    elif stats['Tm'][i] == 'GSW' and stats['Year'][i] == 1986:
        TmWin[i] = 30
    elif stats['Tm'][i] == 'GSW' and stats['Year'][i] == 1987:
        TmWin[i] = 42
    elif stats['Tm'][i] == 'GSW' and stats['Year'][i] == 1988:
        TmWin[i] = 20
    elif stats['Tm'][i] == 'GSW' and stats['Year'][i] == 1989:
        TmWin[i] = 43
    elif stats['Tm'][i] == 'GSW' and stats['Year'][i] == 1990:
        TmWin[i] = 37
    elif stats['Tm'][i] == 'GSW' and stats['Year'][i] == 1991:
        TmWin[i] = 44
    elif stats['Tm'][i] == 'GSW' and stats['Year'][i] == 1992:
        TmWin[i] = 55
    elif stats['Tm'][i] == 'GSW' and stats['Year'][i] == 1993:
        TmWin[i] = 34
    elif stats['Tm'][i] == 'GSW' and stats['Year'][i] == 1994:
        TmWin[i] = 50
    elif stats['Tm'][i] == 'GSW' and stats['Year'][i] == 1995:
        TmWin[i] = 26
    elif stats['Tm'][i] == 'GSW' and stats['Year'][i] == 1996:
        TmWin[i] = 36
    elif stats['Tm'][i] == 'GSW' and stats['Year'][i] == 1997:
        TmWin[i] = 30
    elif stats['Tm'][i] == 'GSW' and stats['Year'][i] == 1998:
        TmWin[i] = 19
    elif stats['Tm'][i] == 'GSW' and stats['Year'][i] == 1999:
        TmWin[i] = 21
    elif stats['Tm'][i] == 'GSW' and stats['Year'][i] == 2000:
        TmWin[i] = 19
    elif stats['Tm'][i] == 'GSW' and stats['Year'][i] == 2001:
        TmWin[i] = 17
    elif stats['Tm'][i] == 'GSW' and stats['Year'][i] == 2002:
        TmWin[i] = 21
    elif stats['Tm'][i] == 'GSW' and stats['Year'][i] == 2003:
        TmWin[i] = 38
    elif stats['Tm'][i] == 'GSW' and stats['Year'][i] == 2004:
        TmWin[i] = 37
    elif stats['Tm'][i] == 'GSW' and stats['Year'][i] == 2005:
        TmWin[i] = 34
    elif stats['Tm'][i] == 'GSW' and stats['Year'][i] == 2006:
        TmWin[i] = 34
    elif stats['Tm'][i] == 'GSW' and stats['Year'][i] == 2007:
        TmWin[i] = 42
    elif stats['Tm'][i] == 'GSW' and stats['Year'][i] == 2008:
        TmWin[i] = 48
    elif stats['Tm'][i] == 'GSW' and stats['Year'][i] == 2009:
        TmWin[i] = 29
    elif stats['Tm'][i] == 'GSW' and stats['Year'][i] == 2010:
        TmWin[i] = 26
    elif stats['Tm'][i] == 'GSW' and stats['Year'][i] == 2011:
        TmWin[i] = 36
    elif stats['Tm'][i] == 'GSW' and stats['Year'][i] == 2012:
        TmWin[i] = 23
    elif stats['Tm'][i] == 'GSW' and stats['Year'][i] == 2013:
        TmWin[i] = 47
    elif stats['Tm'][i] == 'GSW' and stats['Year'][i] == 2014:
        TmWin[i] = 51
    elif stats['Tm'][i] == 'GSW' and stats['Year'][i] == 2015:
        TmWin[i] = 67
    elif stats['Tm'][i] == 'GSW' and stats['Year'][i] == 2016:
        TmWin[i] = 73
    elif stats['Tm'][i] == 'GSW' and stats['Year'][i] == 2017:
        TmWin[i] = 67
    elif stats['Tm'][i] == 'GSW' and stats['Year'][i] == 2018:
        TmWin[i] = 58
    elif stats['Tm'][i] == 'GSW' and stats['Year'][i] == 2019:
        TmWin[i] = 57
    
    # For Knicks
    elif stats['Tm'][i] == 'NYK' and stats['Year'][i] == 1978:
        TmWin[i] = 43
    elif stats['Tm'][i] == 'NYK' and stats['Year'][i] == 1979:
        TmWin[i] = 31
    elif stats['Tm'][i] == 'NYK' and stats['Year'][i] == 1980:
        TmWin[i] = 39
    elif stats['Tm'][i] == 'NYK' and stats['Year'][i] == 1981:
        TmWin[i] = 50
    elif stats['Tm'][i] == 'NYK' and stats['Year'][i] == 1982:
        TmWin[i] = 33
    elif stats['Tm'][i] == 'NYK' and stats['Year'][i] == 1983:
        TmWin[i] = 44
    elif stats['Tm'][i] == 'NYK' and stats['Year'][i] == 1984:
        TmWin[i] = 47
    elif stats['Tm'][i] == 'NYK' and stats['Year'][i] == 1985:
        TmWin[i] = 24
    elif stats['Tm'][i] == 'NYK' and stats['Year'][i] == 1986:
        TmWin[i] = 23
    elif stats['Tm'][i] == 'NYK' and stats['Year'][i] == 1987:
        TmWin[i] = 24
    elif stats['Tm'][i] == 'NYK' and stats['Year'][i] == 1988:
        TmWin[i] = 38
    elif stats['Tm'][i] == 'NYK' and stats['Year'][i] == 1989:
        TmWin[i] = 52
    elif stats['Tm'][i] == 'NYK' and stats['Year'][i] == 1990:
        TmWin[i] = 45
    elif stats['Tm'][i] == 'NYK' and stats['Year'][i] == 1991:
        TmWin[i] = 39
    elif stats['Tm'][i] == 'NYK' and stats['Year'][i] == 1992:
        TmWin[i] = 51
    elif stats['Tm'][i] == 'NYK' and stats['Year'][i] == 1993:
        TmWin[i] = 60
    elif stats['Tm'][i] == 'NYK' and stats['Year'][i] == 1994:
        TmWin[i] = 57
    elif stats['Tm'][i] == 'NYK' and stats['Year'][i] == 1995:
        TmWin[i] = 55
    elif stats['Tm'][i] == 'NYK' and stats['Year'][i] == 1996:
        TmWin[i] = 47
    elif stats['Tm'][i] == 'NYK' and stats['Year'][i] == 1997:
        TmWin[i] = 57
    elif stats['Tm'][i] == 'NYK' and stats['Year'][i] == 1998:
        TmWin[i] = 43
    elif stats['Tm'][i] == 'NYK' and stats['Year'][i] == 1999:
        TmWin[i] = 27
    elif stats['Tm'][i] == 'NYK' and stats['Year'][i] == 2000:
        TmWin[i] = 50
    elif stats['Tm'][i] == 'NYK' and stats['Year'][i] == 2001:
        TmWin[i] = 48
    elif stats['Tm'][i] == 'NYK' and stats['Year'][i] == 2002:
        TmWin[i] = 30
    elif stats['Tm'][i] == 'NYK' and stats['Year'][i] == 2003:
        TmWin[i] = 37
    elif stats['Tm'][i] == 'NYK' and stats['Year'][i] == 2004:
        TmWin[i] = 39
    elif stats['Tm'][i] == 'NYK' and stats['Year'][i] == 2005:
        TmWin[i] = 33
    elif stats['Tm'][i] == 'NYK' and stats['Year'][i] == 2006:
        TmWin[i] = 23
    elif stats['Tm'][i] == 'NYK' and stats['Year'][i] == 2007:
        TmWin[i] = 33
    elif stats['Tm'][i] == 'NYK' and stats['Year'][i] == 2008:
        TmWin[i] = 23
    elif stats['Tm'][i] == 'NYK' and stats['Year'][i] == 2009:
        TmWin[i] = 32
    elif stats['Tm'][i] == 'NYK' and stats['Year'][i] == 2010:
        TmWin[i] = 29
    elif stats['Tm'][i] == 'NYK' and stats['Year'][i] == 2011:
        TmWin[i] = 42
    elif stats['Tm'][i] == 'NYK' and stats['Year'][i] == 2012:
        TmWin[i] = 36
    elif stats['Tm'][i] == 'NYK' and stats['Year'][i] == 2013:
        TmWin[i] = 54
    elif stats['Tm'][i] == 'NYK' and stats['Year'][i] == 2014:
        TmWin[i] = 37
    elif stats['Tm'][i] == 'NYK' and stats['Year'][i] == 2015:
        TmWin[i] = 17
    elif stats['Tm'][i] == 'NYK' and stats['Year'][i] == 2016:
        TmWin[i] = 32
    elif stats['Tm'][i] == 'NYK' and stats['Year'][i] == 2017:
        TmWin[i] = 31
    elif stats['Tm'][i] == 'NYK' and stats['Year'][i] == 2018:
        TmWin[i] = 29
    elif stats['Tm'][i] == 'NYK' and stats['Year'][i] == 2019:
        TmWin[i] = 17
    
    # For Bucks
    elif stats['Tm'][i] == 'MIL' and stats['Year'][i] == 1978:
        TmWin[i] = 44
    elif stats['Tm'][i] == 'MIL' and stats['Year'][i] == 1979:
        TmWin[i] = 38
    elif stats['Tm'][i] == 'MIL' and stats['Year'][i] == 1980:
        TmWin[i] = 49
    elif stats['Tm'][i] == 'MIL' and stats['Year'][i] == 1981:
        TmWin[i] = 60
    elif stats['Tm'][i] == 'MIL' and stats['Year'][i] == 1982:
        TmWin[i] = 55
    elif stats['Tm'][i] == 'MIL' and stats['Year'][i] == 1983:
        TmWin[i] = 51
    elif stats['Tm'][i] == 'MIL' and stats['Year'][i] == 1984:
        TmWin[i] = 50
    elif stats['Tm'][i] == 'MIL' and stats['Year'][i] == 1985:
        TmWin[i] = 59
    elif stats['Tm'][i] == 'MIL' and stats['Year'][i] == 1986:
        TmWin[i] = 57
    elif stats['Tm'][i] == 'MIL' and stats['Year'][i] == 1987:
        TmWin[i] = 50
    elif stats['Tm'][i] == 'MIL' and stats['Year'][i] == 1988:
        TmWin[i] = 42
    elif stats['Tm'][i] == 'MIL' and stats['Year'][i] == 1989:
        TmWin[i] = 49
    elif stats['Tm'][i] == 'MIL' and stats['Year'][i] == 1990:
        TmWin[i] = 44
    elif stats['Tm'][i] == 'MIL' and stats['Year'][i] == 1991:
        TmWin[i] = 48
    elif stats['Tm'][i] == 'MIL' and stats['Year'][i] == 1992:
        TmWin[i] = 31
    elif stats['Tm'][i] == 'MIL' and stats['Year'][i] == 1993:
        TmWin[i] = 28
    elif stats['Tm'][i] == 'MIL' and stats['Year'][i] == 1994:
        TmWin[i] = 20
    elif stats['Tm'][i] == 'MIL' and stats['Year'][i] == 1995:
        TmWin[i] = 34
    elif stats['Tm'][i] == 'MIL' and stats['Year'][i] == 1996:
        TmWin[i] = 25
    elif stats['Tm'][i] == 'MIL' and stats['Year'][i] == 1997:
        TmWin[i] = 33
    elif stats['Tm'][i] == 'MIL' and stats['Year'][i] == 1998:
        TmWin[i] = 36
    elif stats['Tm'][i] == 'MIL' and stats['Year'][i] == 1999:
        TmWin[i] = 28
    elif stats['Tm'][i] == 'MIL' and stats['Year'][i] == 2000:
        TmWin[i] = 42
    elif stats['Tm'][i] == 'MIL' and stats['Year'][i] == 2001:
        TmWin[i] = 52
    elif stats['Tm'][i] == 'MIL' and stats['Year'][i] == 2002:
        TmWin[i] = 41
    elif stats['Tm'][i] == 'MIL' and stats['Year'][i] == 2003:
        TmWin[i] = 42
    elif stats['Tm'][i] == 'MIL' and stats['Year'][i] == 2004:
        TmWin[i] = 41
    elif stats['Tm'][i] == 'MIL' and stats['Year'][i] == 2005:
        TmWin[i] = 30
    elif stats['Tm'][i] == 'MIL' and stats['Year'][i] == 2006:
        TmWin[i] = 40
    elif stats['Tm'][i] == 'MIL' and stats['Year'][i] == 2007:
        TmWin[i] = 28
    elif stats['Tm'][i] == 'MIL' and stats['Year'][i] == 2008:
        TmWin[i] = 26
    elif stats['Tm'][i] == 'MIL' and stats['Year'][i] == 2009:
        TmWin[i] = 34
    elif stats['Tm'][i] == 'MIL' and stats['Year'][i] == 2010:
        TmWin[i] = 46
    elif stats['Tm'][i] == 'MIL' and stats['Year'][i] == 2011:
        TmWin[i] = 35
    elif stats['Tm'][i] == 'MIL' and stats['Year'][i] == 2012:
        TmWin[i] = 31
    elif stats['Tm'][i] == 'MIL' and stats['Year'][i] == 2013:
        TmWin[i] = 38
    elif stats['Tm'][i] == 'MIL' and stats['Year'][i] == 2014:
        TmWin[i] = 15
    elif stats['Tm'][i] == 'MIL' and stats['Year'][i] == 2015:
        TmWin[i] = 41
    elif stats['Tm'][i] == 'MIL' and stats['Year'][i] == 2016:
        TmWin[i] = 33
    elif stats['Tm'][i] == 'MIL' and stats['Year'][i] == 2017:
        TmWin[i] = 42
    elif stats['Tm'][i] == 'MIL' and stats['Year'][i] == 2018:
        TmWin[i] = 44
    elif stats['Tm'][i] == 'MIL' and stats['Year'][i] == 2019:
        TmWin[i] = 60
    
    # For Philly
    elif stats['Tm'][i] == 'PHI' and stats['Year'][i] == 1978:
        TmWin[i] = 55
    elif stats['Tm'][i] == 'PHI' and stats['Year'][i] == 1979:
        TmWin[i] = 47
    elif stats['Tm'][i] == 'PHI' and stats['Year'][i] == 1980:
        TmWin[i] = 59
    elif stats['Tm'][i] == 'PHI' and stats['Year'][i] == 1981:
        TmWin[i] = 62
    elif stats['Tm'][i] == 'PHI' and stats['Year'][i] == 1982:
        TmWin[i] = 58
    elif stats['Tm'][i] == 'PHI' and stats['Year'][i] == 1983:
        TmWin[i] = 65
    elif stats['Tm'][i] == 'PHI' and stats['Year'][i] == 1984:
        TmWin[i] = 52
    elif stats['Tm'][i] == 'PHI' and stats['Year'][i] == 1985:
        TmWin[i] = 58
    elif stats['Tm'][i] == 'PHI' and stats['Year'][i] == 1986:
        TmWin[i] = 54
    elif stats['Tm'][i] == 'PHI' and stats['Year'][i] == 1987:
        TmWin[i] = 45
    elif stats['Tm'][i] == 'PHI' and stats['Year'][i] == 1988:
        TmWin[i] = 36
    elif stats['Tm'][i] == 'PHI' and stats['Year'][i] == 1989:
        TmWin[i] = 46
    elif stats['Tm'][i] == 'PHI' and stats['Year'][i] == 1990:
        TmWin[i] = 53
    elif stats['Tm'][i] == 'PHI' and stats['Year'][i] == 1991:
        TmWin[i] = 44
    elif stats['Tm'][i] == 'PHI' and stats['Year'][i] == 1992:
        TmWin[i] = 35
    elif stats['Tm'][i] == 'PHI' and stats['Year'][i] == 1993:
        TmWin[i] = 26
    elif stats['Tm'][i] == 'PHI' and stats['Year'][i] == 1994:
        TmWin[i] = 25
    elif stats['Tm'][i] == 'PHI' and stats['Year'][i] == 1995:
        TmWin[i] = 24
    elif stats['Tm'][i] == 'PHI' and stats['Year'][i] == 1996:
        TmWin[i] = 18
    elif stats['Tm'][i] == 'PHI' and stats['Year'][i] == 1997:
        TmWin[i] = 22
    elif stats['Tm'][i] == 'PHI' and stats['Year'][i] == 1998:
        TmWin[i] = 31
    elif stats['Tm'][i] == 'PHI' and stats['Year'][i] == 1999:
        TmWin[i] = 28
    elif stats['Tm'][i] == 'PHI' and stats['Year'][i] == 2000:
        TmWin[i] = 49
    elif stats['Tm'][i] == 'PHI' and stats['Year'][i] == 2001:
        TmWin[i] = 56
    elif stats['Tm'][i] == 'PHI' and stats['Year'][i] == 2002:
        TmWin[i] = 43
    elif stats['Tm'][i] == 'PHI' and stats['Year'][i] == 2003:
        TmWin[i] = 48
    elif stats['Tm'][i] == 'PHI' and stats['Year'][i] == 2004:
        TmWin[i] = 33
    elif stats['Tm'][i] == 'PHI' and stats['Year'][i] == 2005:
        TmWin[i] = 43
    elif stats['Tm'][i] == 'PHI' and stats['Year'][i] == 2006:
        TmWin[i] = 38
    elif stats['Tm'][i] == 'PHI' and stats['Year'][i] == 2007:
        TmWin[i] = 35
    elif stats['Tm'][i] == 'PHI' and stats['Year'][i] == 2008:
        TmWin[i] = 40
    elif stats['Tm'][i] == 'PHI' and stats['Year'][i] == 2009:
        TmWin[i] = 41
    elif stats['Tm'][i] == 'PHI' and stats['Year'][i] == 2010:
        TmWin[i] = 27
    elif stats['Tm'][i] == 'PHI' and stats['Year'][i] == 2011:
        TmWin[i] = 41
    elif stats['Tm'][i] == 'PHI' and stats['Year'][i] == 2012:
        TmWin[i] = 35
    elif stats['Tm'][i] == 'PHI' and stats['Year'][i] == 2013:
        TmWin[i] = 34
    elif stats['Tm'][i] == 'PHI' and stats['Year'][i] == 2014:
        TmWin[i] = 19
    elif stats['Tm'][i] == 'PHI' and stats['Year'][i] == 2015:
        TmWin[i] = 18
    elif stats['Tm'][i] == 'PHI' and stats['Year'][i] == 2016:
        TmWin[i] = 10
    elif stats['Tm'][i] == 'PHI' and stats['Year'][i] == 2017:
        TmWin[i] = 28
    elif stats['Tm'][i] == 'PHI' and stats['Year'][i] == 2018:
        TmWin[i] = 52
    elif stats['Tm'][i] == 'PHI' and stats['Year'][i] == 2019:
        TmWin[i] = 51
    
    # For Cavs
    elif stats['Tm'][i] == 'CLE' and stats['Year'][i] == 1978:
        TmWin[i] = 43
    elif stats['Tm'][i] == 'CLE' and stats['Year'][i] == 1979:
        TmWin[i] = 30
    elif stats['Tm'][i] == 'CLE' and stats['Year'][i] == 1980:
        TmWin[i] = 37
    elif stats['Tm'][i] == 'CLE' and stats['Year'][i] == 1981:
        TmWin[i] = 28
    elif stats['Tm'][i] == 'CLE' and stats['Year'][i] == 1982:
        TmWin[i] = 15
    elif stats['Tm'][i] == 'CLE' and stats['Year'][i] == 1983:
        TmWin[i] = 23
    elif stats['Tm'][i] == 'CLE' and stats['Year'][i] == 1984:
        TmWin[i] = 28
    elif stats['Tm'][i] == 'CLE' and stats['Year'][i] == 1985:
        TmWin[i] = 36
    elif stats['Tm'][i] == 'CLE' and stats['Year'][i] == 1986:
        TmWin[i] = 29
    elif stats['Tm'][i] == 'CLE' and stats['Year'][i] == 1987:
        TmWin[i] = 31
    elif stats['Tm'][i] == 'CLE' and stats['Year'][i] == 1988:
        TmWin[i] = 42
    elif stats['Tm'][i] == 'CLE' and stats['Year'][i] == 1989:
        TmWin[i] = 57
    elif stats['Tm'][i] == 'CLE' and stats['Year'][i] == 1990:
        TmWin[i] = 42
    elif stats['Tm'][i] == 'CLE' and stats['Year'][i] == 1991:
        TmWin[i] = 33
    elif stats['Tm'][i] == 'CLE' and stats['Year'][i] == 1992:
        TmWin[i] = 57
    elif stats['Tm'][i] == 'CLE' and stats['Year'][i] == 1993:
        TmWin[i] = 54
    elif stats['Tm'][i] == 'CLE' and stats['Year'][i] == 1994:
        TmWin[i] = 47
    elif stats['Tm'][i] == 'CLE' and stats['Year'][i] == 1995:
        TmWin[i] = 43
    elif stats['Tm'][i] == 'CLE' and stats['Year'][i] == 1996:
        TmWin[i] = 47
    elif stats['Tm'][i] == 'CLE' and stats['Year'][i] == 1997:
        TmWin[i] = 42
    elif stats['Tm'][i] == 'CLE' and stats['Year'][i] == 1998:
        TmWin[i] = 47
    elif stats['Tm'][i] == 'CLE' and stats['Year'][i] == 1999:
        TmWin[i] = 22
    elif stats['Tm'][i] == 'CLE' and stats['Year'][i] == 2000:
        TmWin[i] = 32
    elif stats['Tm'][i] == 'CLE' and stats['Year'][i] == 2001:
        TmWin[i] = 30
    elif stats['Tm'][i] == 'CLE' and stats['Year'][i] == 2002:
        TmWin[i] = 29
    elif stats['Tm'][i] == 'CLE' and stats['Year'][i] == 2003:
        TmWin[i] = 17
    elif stats['Tm'][i] == 'CLE' and stats['Year'][i] == 2004:
        TmWin[i] = 35
    elif stats['Tm'][i] == 'CLE' and stats['Year'][i] == 2005:
        TmWin[i] = 42
    elif stats['Tm'][i] == 'CLE' and stats['Year'][i] == 2006:
        TmWin[i] = 50
    elif stats['Tm'][i] == 'CLE' and stats['Year'][i] == 2007:
        TmWin[i] = 50
    elif stats['Tm'][i] == 'CLE' and stats['Year'][i] == 2008:
        TmWin[i] = 45
    elif stats['Tm'][i] == 'CLE' and stats['Year'][i] == 2009:
        TmWin[i] = 66
    elif stats['Tm'][i] == 'CLE' and stats['Year'][i] == 2010:
        TmWin[i] = 61
    elif stats['Tm'][i] == 'CLE' and stats['Year'][i] == 2011:
        TmWin[i] = 19
    elif stats['Tm'][i] == 'CLE' and stats['Year'][i] == 2012:
        TmWin[i] = 21
    elif stats['Tm'][i] == 'CLE' and stats['Year'][i] == 2013:
        TmWin[i] = 24
    elif stats['Tm'][i] == 'CLE' and stats['Year'][i] == 2014:
        TmWin[i] = 33
    elif stats['Tm'][i] == 'CLE' and stats['Year'][i] == 2015:
        TmWin[i] = 53
    elif stats['Tm'][i] == 'CLE' and stats['Year'][i] == 2016:
        TmWin[i] = 57
    elif stats['Tm'][i] == 'CLE' and stats['Year'][i] == 2017:
        TmWin[i] = 51
    elif stats['Tm'][i] == 'CLE' and stats['Year'][i] == 2018:
        TmWin[i] = 50
    elif stats['Tm'][i] == 'CLE' and stats['Year'][i] == 2019:
        TmWin[i] = 19
    
    # For the spurs
    elif stats['Tm'][i] == 'SAS' and stats['Year'][i] == 1978:
        TmWin[i] = 52
    elif stats['Tm'][i] == 'SAS' and stats['Year'][i] == 1979:
        TmWin[i] = 48
    elif stats['Tm'][i] == 'SAS' and stats['Year'][i] == 1980:
        TmWin[i] = 41
    elif stats['Tm'][i] == 'SAS' and stats['Year'][i] == 1981:
        TmWin[i] = 52
    elif stats['Tm'][i] == 'SAS' and stats['Year'][i] == 1982:
        TmWin[i] = 48
    elif stats['Tm'][i] == 'SAS' and stats['Year'][i] == 1983:
        TmWin[i] = 53
    elif stats['Tm'][i] == 'SAS' and stats['Year'][i] == 1984:
        TmWin[i] = 37
    elif stats['Tm'][i] == 'SAS' and stats['Year'][i] == 1985:
        TmWin[i] = 41
    elif stats['Tm'][i] == 'SAS' and stats['Year'][i] == 1986:
        TmWin[i] = 35
    elif stats['Tm'][i] == 'SAS' and stats['Year'][i] == 1987:
        TmWin[i] = 28
    elif stats['Tm'][i] == 'SAS' and stats['Year'][i] == 1988:
        TmWin[i] = 31
    elif stats['Tm'][i] == 'SAS' and stats['Year'][i] == 1989:
        TmWin[i] = 21
    elif stats['Tm'][i] == 'SAS' and stats['Year'][i] == 1990:
        TmWin[i] = 56
    elif stats['Tm'][i] == 'SAS' and stats['Year'][i] == 1991:
        TmWin[i] = 55
    elif stats['Tm'][i] == 'SAS' and stats['Year'][i] == 1992:
        TmWin[i] = 47
    elif stats['Tm'][i] == 'SAS' and stats['Year'][i] == 1993:
        TmWin[i] = 49
    elif stats['Tm'][i] == 'SAS' and stats['Year'][i] == 1994:
        TmWin[i] = 55
    elif stats['Tm'][i] == 'SAS' and stats['Year'][i] == 1995:
        TmWin[i] = 62
    elif stats['Tm'][i] == 'SAS' and stats['Year'][i] == 1996:
        TmWin[i] = 59
    elif stats['Tm'][i] == 'SAS' and stats['Year'][i] == 1997:
        TmWin[i] = 20
    elif stats['Tm'][i] == 'SAS' and stats['Year'][i] == 1998:
        TmWin[i] = 56
    elif stats['Tm'][i] == 'SAS' and stats['Year'][i] == 1999:
        TmWin[i] = 37
    elif stats['Tm'][i] == 'SAS' and stats['Year'][i] == 2000:
        TmWin[i] = 53
    elif stats['Tm'][i] == 'SAS' and stats['Year'][i] == 2001:
        TmWin[i] = 58
    elif stats['Tm'][i] == 'SAS' and stats['Year'][i] == 2002:
        TmWin[i] = 58
    elif stats['Tm'][i] == 'SAS' and stats['Year'][i] == 2003:
        TmWin[i] = 60
    elif stats['Tm'][i] == 'SAS' and stats['Year'][i] == 2004:
        TmWin[i] = 57
    elif stats['Tm'][i] == 'SAS' and stats['Year'][i] == 2005:
        TmWin[i] = 59
    elif stats['Tm'][i] == 'SAS' and stats['Year'][i] == 2006:
        TmWin[i] = 63
    elif stats['Tm'][i] == 'SAS' and stats['Year'][i] == 2007:
        TmWin[i] = 58
    elif stats['Tm'][i] == 'SAS' and stats['Year'][i] == 2008:
        TmWin[i] = 56
    elif stats['Tm'][i] == 'SAS' and stats['Year'][i] == 2009:
        TmWin[i] = 54
    elif stats['Tm'][i] == 'SAS' and stats['Year'][i] == 2010:
        TmWin[i] = 50
    elif stats['Tm'][i] == 'SAS' and stats['Year'][i] == 2011:
        TmWin[i] = 61
    elif stats['Tm'][i] == 'SAS' and stats['Year'][i] == 2012:
        TmWin[i] = 50
    elif stats['Tm'][i] == 'SAS' and stats['Year'][i] == 2013:
        TmWin[i] = 58
    elif stats['Tm'][i] == 'SAS' and stats['Year'][i] == 2014:
        TmWin[i] = 62
    elif stats['Tm'][i] == 'SAS' and stats['Year'][i] == 2015:
        TmWin[i] = 55
    elif stats['Tm'][i] == 'SAS' and stats['Year'][i] == 2016:
        TmWin[i] = 67
    elif stats['Tm'][i] == 'SAS' and stats['Year'][i] == 2017:
        TmWin[i] = 61
    elif stats['Tm'][i] == 'SAS' and stats['Year'][i] == 2018:
        TmWin[i] = 47
    elif stats['Tm'][i] == 'SAS' and stats['Year'][i] == 2019:
        TmWin[i] = 48
    
    # For Portland
    elif stats['Tm'][i] == 'POR' and stats['Year'][i] == 1978:
        TmWin[i] = 58
    elif stats['Tm'][i] == 'POR' and stats['Year'][i] == 1979:
        TmWin[i] = 45
    elif stats['Tm'][i] == 'POR' and stats['Year'][i] == 1980:
        TmWin[i] = 38
    elif stats['Tm'][i] == 'POR' and stats['Year'][i] == 1981:
        TmWin[i] = 45
    elif stats['Tm'][i] == 'POR' and stats['Year'][i] == 1982:
        TmWin[i] = 42
    elif stats['Tm'][i] == 'POR' and stats['Year'][i] == 1983:
        TmWin[i] = 46
    elif stats['Tm'][i] == 'POR' and stats['Year'][i] == 1984:
        TmWin[i] = 48
    elif stats['Tm'][i] == 'POR' and stats['Year'][i] == 1985:
        TmWin[i] = 42
    elif stats['Tm'][i] == 'POR' and stats['Year'][i] == 1986:
        TmWin[i] = 40
    elif stats['Tm'][i] == 'POR' and stats['Year'][i] == 1987:
        TmWin[i] = 49
    elif stats['Tm'][i] == 'POR' and stats['Year'][i] == 1988:
        TmWin[i] = 53
    elif stats['Tm'][i] == 'POR' and stats['Year'][i] == 1989:
        TmWin[i] = 39
    elif stats['Tm'][i] == 'POR' and stats['Year'][i] == 1990:
        TmWin[i] = 59
    elif stats['Tm'][i] == 'POR' and stats['Year'][i] == 1991:
        TmWin[i] = 63
    elif stats['Tm'][i] == 'POR' and stats['Year'][i] == 1992:
        TmWin[i] = 57
    elif stats['Tm'][i] == 'POR' and stats['Year'][i] == 1993:
        TmWin[i] = 51
    elif stats['Tm'][i] == 'POR' and stats['Year'][i] == 1994:
        TmWin[i] = 47
    elif stats['Tm'][i] == 'POR' and stats['Year'][i] == 1995:
        TmWin[i] = 44
    elif stats['Tm'][i] == 'POR' and stats['Year'][i] == 1996:
        TmWin[i] = 44
    elif stats['Tm'][i] == 'POR' and stats['Year'][i] == 1997:
        TmWin[i] = 49
    elif stats['Tm'][i] == 'POR' and stats['Year'][i] == 1998:
        TmWin[i] = 46
    elif stats['Tm'][i] == 'POR' and stats['Year'][i] == 1999:
        TmWin[i] = 35
    elif stats['Tm'][i] == 'POR' and stats['Year'][i] == 2000:
        TmWin[i] = 59
    elif stats['Tm'][i] == 'POR' and stats['Year'][i] == 2001:
        TmWin[i] = 50
    elif stats['Tm'][i] == 'POR' and stats['Year'][i] == 2002:
        TmWin[i] = 49
    elif stats['Tm'][i] == 'POR' and stats['Year'][i] == 2003:
        TmWin[i] = 50
    elif stats['Tm'][i] == 'POR' and stats['Year'][i] == 2004:
        TmWin[i] = 41
    elif stats['Tm'][i] == 'POR' and stats['Year'][i] == 2005:
        TmWin[i] = 27
    elif stats['Tm'][i] == 'POR' and stats['Year'][i] == 2006:
        TmWin[i] = 21
    elif stats['Tm'][i] == 'POR' and stats['Year'][i] == 2007:
        TmWin[i] = 32
    elif stats['Tm'][i] == 'POR' and stats['Year'][i] == 2008:
        TmWin[i] = 41
    elif stats['Tm'][i] == 'POR' and stats['Year'][i] == 2009:
        TmWin[i] = 54
    elif stats['Tm'][i] == 'POR' and stats['Year'][i] == 2010:
        TmWin[i] = 50
    elif stats['Tm'][i] == 'POR' and stats['Year'][i] == 2011:
        TmWin[i] = 48
    elif stats['Tm'][i] == 'POR' and stats['Year'][i] == 2012:
        TmWin[i] = 28
    elif stats['Tm'][i] == 'POR' and stats['Year'][i] == 2013:
        TmWin[i] = 33
    elif stats['Tm'][i] == 'POR' and stats['Year'][i] == 2014:
        TmWin[i] = 54
    elif stats['Tm'][i] == 'POR' and stats['Year'][i] == 2015:
        TmWin[i] = 51
    elif stats['Tm'][i] == 'POR' and stats['Year'][i] == 2016:
        TmWin[i] = 44
    elif stats['Tm'][i] == 'POR' and stats['Year'][i] == 2017:
        TmWin[i] = 41
    elif stats['Tm'][i] == 'POR' and stats['Year'][i] == 2018:
        TmWin[i] = 49
    elif stats['Tm'][i] == 'POR' and stats['Year'][i] == 2019:
        TmWin[i] = 53
    
    # For Nuggets
    elif stats['Tm'][i] == 'DEN' and stats['Year'][i] == 1978:
        TmWin[i] = 48
    elif stats['Tm'][i] == 'DEN' and stats['Year'][i] == 1979:
        TmWin[i] = 47
    elif stats['Tm'][i] == 'DEN' and stats['Year'][i] == 1980:
        TmWin[i] = 39
    elif stats['Tm'][i] == 'DEN' and stats['Year'][i] == 1981:
        TmWin[i] = 37
    elif stats['Tm'][i] == 'DEN' and stats['Year'][i] == 1982:
        TmWin[i] = 46
    elif stats['Tm'][i] == 'DEN' and stats['Year'][i] == 1983:
        TmWin[i] = 45
    elif stats['Tm'][i] == 'DEN' and stats['Year'][i] == 1984:
        TmWin[i] = 38
    elif stats['Tm'][i] == 'DEN' and stats['Year'][i] == 1985:
        TmWin[i] = 52
    elif stats['Tm'][i] == 'DEN' and stats['Year'][i] == 1986:
        TmWin[i] = 47
    elif stats['Tm'][i] == 'DEN' and stats['Year'][i] == 1987:
        TmWin[i] = 37
    elif stats['Tm'][i] == 'DEN' and stats['Year'][i] == 1988:
        TmWin[i] = 54
    elif stats['Tm'][i] == 'DEN' and stats['Year'][i] == 1989:
        TmWin[i] = 44
    elif stats['Tm'][i] == 'DEN' and stats['Year'][i] == 1990:
        TmWin[i] = 43
    elif stats['Tm'][i] == 'DEN' and stats['Year'][i] == 1991:
        TmWin[i] = 20
    elif stats['Tm'][i] == 'DEN' and stats['Year'][i] == 1992:
        TmWin[i] = 24
    elif stats['Tm'][i] == 'DEN' and stats['Year'][i] == 1993:
        TmWin[i] = 36
    elif stats['Tm'][i] == 'DEN' and stats['Year'][i] == 1994:
        TmWin[i] = 42
    elif stats['Tm'][i] == 'DEN' and stats['Year'][i] == 1995:
        TmWin[i] = 41
    elif stats['Tm'][i] == 'DEN' and stats['Year'][i] == 1996:
        TmWin[i] = 35
    elif stats['Tm'][i] == 'DEN' and stats['Year'][i] == 1997:
        TmWin[i] = 21
    elif stats['Tm'][i] == 'DEN' and stats['Year'][i] == 1998:
        TmWin[i] = 11
    elif stats['Tm'][i] == 'DEN' and stats['Year'][i] == 1999:
        TmWin[i] = 14
    elif stats['Tm'][i] == 'DEN' and stats['Year'][i] == 2000:
        TmWin[i] = 35
    elif stats['Tm'][i] == 'DEN' and stats['Year'][i] == 2001:
        TmWin[i] = 40
    elif stats['Tm'][i] == 'DEN' and stats['Year'][i] == 2002:
        TmWin[i] = 27
    elif stats['Tm'][i] == 'DEN' and stats['Year'][i] == 2003:
        TmWin[i] = 17
    elif stats['Tm'][i] == 'DEN' and stats['Year'][i] == 2004:
        TmWin[i] = 43
    elif stats['Tm'][i] == 'DEN' and stats['Year'][i] == 2005:
        TmWin[i] = 49
    elif stats['Tm'][i] == 'DEN' and stats['Year'][i] == 2006:
        TmWin[i] = 44
    elif stats['Tm'][i] == 'DEN' and stats['Year'][i] == 2007:
        TmWin[i] = 45
    elif stats['Tm'][i] == 'DEN' and stats['Year'][i] == 2008:
        TmWin[i] = 50
    elif stats['Tm'][i] == 'DEN' and stats['Year'][i] == 2009:
        TmWin[i] = 54
    elif stats['Tm'][i] == 'DEN' and stats['Year'][i] == 2010:
        TmWin[i] = 53
    elif stats['Tm'][i] == 'DEN' and stats['Year'][i] == 2011:
        TmWin[i] = 50
    elif stats['Tm'][i] == 'DEN' and stats['Year'][i] == 2012:
        TmWin[i] = 38
    elif stats['Tm'][i] == 'DEN' and stats['Year'][i] == 2013:
        TmWin[i] = 57
    elif stats['Tm'][i] == 'DEN' and stats['Year'][i] == 2014:
        TmWin[i] = 36
    elif stats['Tm'][i] == 'DEN' and stats['Year'][i] == 2015:
        TmWin[i] = 30
    elif stats['Tm'][i] == 'DEN' and stats['Year'][i] == 2016:
        TmWin[i] = 33
    elif stats['Tm'][i] == 'DEN' and stats['Year'][i] == 2017:
        TmWin[i] = 40
    elif stats['Tm'][i] == 'DEN' and stats['Year'][i] == 2018:
        TmWin[i] = 46
    elif stats['Tm'][i] == 'DEN' and stats['Year'][i] == 2019:
        TmWin[i] = 54
    
    # For Utah Jazz
    elif stats['Tm'][i] == 'UTA' and stats['Year'][i] == 1980:
        TmWin[i] = 24
    elif stats['Tm'][i] == 'UTA' and stats['Year'][i] == 1981:
        TmWin[i] = 28
    elif stats['Tm'][i] == 'UTA' and stats['Year'][i] == 1982:
        TmWin[i] = 25
    elif stats['Tm'][i] == 'UTA' and stats['Year'][i] == 1983:
        TmWin[i] = 30
    elif stats['Tm'][i] == 'UTA' and stats['Year'][i] == 1984:
        TmWin[i] = 45
    elif stats['Tm'][i] == 'UTA' and stats['Year'][i] == 1985:
        TmWin[i] = 41
    elif stats['Tm'][i] == 'UTA' and stats['Year'][i] == 1986:
        TmWin[i] = 42
    elif stats['Tm'][i] == 'UTA' and stats['Year'][i] == 1987:
        TmWin[i] = 44
    elif stats['Tm'][i] == 'UTA' and stats['Year'][i] == 1988:
        TmWin[i] = 47
    elif stats['Tm'][i] == 'UTA' and stats['Year'][i] == 1989:
        TmWin[i] = 51
    elif stats['Tm'][i] == 'UTA' and stats['Year'][i] == 1990:
        TmWin[i] = 55
    elif stats['Tm'][i] == 'UTA' and stats['Year'][i] == 1991:
        TmWin[i] = 54
    elif stats['Tm'][i] == 'UTA' and stats['Year'][i] == 1992:
        TmWin[i] = 55
    elif stats['Tm'][i] == 'UTA' and stats['Year'][i] == 1993:
        TmWin[i] = 47
    elif stats['Tm'][i] == 'UTA' and stats['Year'][i] == 1994:
        TmWin[i] = 53
    elif stats['Tm'][i] == 'UTA' and stats['Year'][i] == 1995:
        TmWin[i] = 60
    elif stats['Tm'][i] == 'UTA' and stats['Year'][i] == 1996:
        TmWin[i] = 55
    elif stats['Tm'][i] == 'UTA' and stats['Year'][i] == 1997:
        TmWin[i] = 64
    elif stats['Tm'][i] == 'UTA' and stats['Year'][i] == 1998:
        TmWin[i] = 62
    elif stats['Tm'][i] == 'UTA' and stats['Year'][i] == 1999:
        TmWin[i] = 37
    elif stats['Tm'][i] == 'UTA' and stats['Year'][i] == 2000:
        TmWin[i] = 55
    elif stats['Tm'][i] == 'UTA' and stats['Year'][i] == 2001:
        TmWin[i] = 53
    elif stats['Tm'][i] == 'UTA' and stats['Year'][i] == 2002:
        TmWin[i] = 44
    elif stats['Tm'][i] == 'UTA' and stats['Year'][i] == 2003:
        TmWin[i] = 47
    elif stats['Tm'][i] == 'UTA' and stats['Year'][i] == 2004:
        TmWin[i] = 42
    elif stats['Tm'][i] == 'UTA' and stats['Year'][i] == 2005:
        TmWin[i] = 26
    elif stats['Tm'][i] == 'UTA' and stats['Year'][i] == 2006:
        TmWin[i] = 41
    elif stats['Tm'][i] == 'UTA' and stats['Year'][i] == 2007:
        TmWin[i] = 51
    elif stats['Tm'][i] == 'UTA' and stats['Year'][i] == 2008:
        TmWin[i] = 54
    elif stats['Tm'][i] == 'UTA' and stats['Year'][i] == 2009:
        TmWin[i] = 48
    elif stats['Tm'][i] == 'UTA' and stats['Year'][i] == 2010:
        TmWin[i] = 53
    elif stats['Tm'][i] == 'UTA' and stats['Year'][i] == 2011:
        TmWin[i] = 39
    elif stats['Tm'][i] == 'UTA' and stats['Year'][i] == 2012:
        TmWin[i] = 36
    elif stats['Tm'][i] == 'UTA' and stats['Year'][i] == 2013:
        TmWin[i] = 43
    elif stats['Tm'][i] == 'UTA' and stats['Year'][i] == 2014:
        TmWin[i] = 25
    elif stats['Tm'][i] == 'UTA' and stats['Year'][i] == 2015:
        TmWin[i] = 38
    elif stats['Tm'][i] == 'UTA' and stats['Year'][i] == 2016:
        TmWin[i] = 40
    elif stats['Tm'][i] == 'UTA' and stats['Year'][i] == 2017:
        TmWin[i] = 51
    elif stats['Tm'][i] == 'UTA' and stats['Year'][i] == 2018:
        TmWin[i] = 48
    elif stats['Tm'][i] == 'UTA' and stats['Year'][i] == 2019:
        TmWin[i] = 50
    
    # For Dallas
    elif stats['Tm'][i] == 'DAL' and stats['Year'][i] == 1981:
        TmWin[i] = 15
    elif stats['Tm'][i] == 'DAL' and stats['Year'][i] == 1982:
        TmWin[i] = 28
    elif stats['Tm'][i] == 'DAL' and stats['Year'][i] == 1983:
        TmWin[i] = 38
    elif stats['Tm'][i] == 'DAL' and stats['Year'][i] == 1984:
        TmWin[i] = 43
    elif stats['Tm'][i] == 'DAL' and stats['Year'][i] == 1985:
        TmWin[i] = 44
    elif stats['Tm'][i] == 'DAL' and stats['Year'][i] == 1986:
        TmWin[i] = 44
    elif stats['Tm'][i] == 'DAL' and stats['Year'][i] == 1987:
        TmWin[i] = 55
    elif stats['Tm'][i] == 'DAL' and stats['Year'][i] == 1988:
        TmWin[i] = 53
    elif stats['Tm'][i] == 'DAL' and stats['Year'][i] == 1989:
        TmWin[i] = 38
    elif stats['Tm'][i] == 'DAL' and stats['Year'][i] == 1990:
        TmWin[i] = 47
    elif stats['Tm'][i] == 'DAL' and stats['Year'][i] == 1991:
        TmWin[i] = 28
    elif stats['Tm'][i] == 'DAL' and stats['Year'][i] == 1992:
        TmWin[i] = 22
    elif stats['Tm'][i] == 'DAL' and stats['Year'][i] == 1993:
        TmWin[i] = 11
    elif stats['Tm'][i] == 'DAL' and stats['Year'][i] == 1994:
        TmWin[i] = 13
    elif stats['Tm'][i] == 'DAL' and stats['Year'][i] == 1995:
        TmWin[i] = 36
    elif stats['Tm'][i] == 'DAL' and stats['Year'][i] == 1996:
        TmWin[i] = 26
    elif stats['Tm'][i] == 'DAL' and stats['Year'][i] == 1997:
        TmWin[i] = 24
    elif stats['Tm'][i] == 'DAL' and stats['Year'][i] == 1998:
        TmWin[i] = 20
    elif stats['Tm'][i] == 'DAL' and stats['Year'][i] == 1999:
        TmWin[i] = 19
    elif stats['Tm'][i] == 'DAL' and stats['Year'][i] == 2000:
        TmWin[i] = 40
    elif stats['Tm'][i] == 'DAL' and stats['Year'][i] == 2001:
        TmWin[i] = 53
    elif stats['Tm'][i] == 'DAL' and stats['Year'][i] == 2002:
        TmWin[i] = 57
    elif stats['Tm'][i] == 'DAL' and stats['Year'][i] == 2003:
        TmWin[i] = 60
    elif stats['Tm'][i] == 'DAL' and stats['Year'][i] == 2004:
        TmWin[i] = 52
    elif stats['Tm'][i] == 'DAL' and stats['Year'][i] == 2005:
        TmWin[i] = 58
    elif stats['Tm'][i] == 'DAL' and stats['Year'][i] == 2006:
        TmWin[i] = 60
    elif stats['Tm'][i] == 'DAL' and stats['Year'][i] == 2007:
        TmWin[i] = 67
    elif stats['Tm'][i] == 'DAL' and stats['Year'][i] == 2008:
        TmWin[i] = 51
    elif stats['Tm'][i] == 'DAL' and stats['Year'][i] == 2009:
        TmWin[i] = 50
    elif stats['Tm'][i] == 'DAL' and stats['Year'][i] == 2010:
        TmWin[i] = 55
    elif stats['Tm'][i] == 'DAL' and stats['Year'][i] == 2011:
        TmWin[i] = 57
    elif stats['Tm'][i] == 'DAL' and stats['Year'][i] == 2012:
        TmWin[i] = 36
    elif stats['Tm'][i] == 'DAL' and stats['Year'][i] == 2013:
        TmWin[i] = 41
    elif stats['Tm'][i] == 'DAL' and stats['Year'][i] == 2014:
        TmWin[i] = 49
    elif stats['Tm'][i] == 'DAL' and stats['Year'][i] == 2015:
        TmWin[i] = 50
    elif stats['Tm'][i] == 'DAL' and stats['Year'][i] == 2016:
        TmWin[i] = 42
    elif stats['Tm'][i] == 'DAL' and stats['Year'][i] == 2017:
        TmWin[i] = 33
    elif stats['Tm'][i] == 'DAL' and stats['Year'][i] == 2018:
        TmWin[i] = 24
    elif stats['Tm'][i] == 'DAL' and stats['Year'][i] == 2019:
        TmWin[i] = 33
    
    # For Clippers
    elif stats['Tm'][i] == 'LAC' and stats['Year'][i] == 1985:
        TmWin[i] = 31
    elif stats['Tm'][i] == 'LAC' and stats['Year'][i] == 1986:
        TmWin[i] = 32
    elif stats['Tm'][i] == 'LAC' and stats['Year'][i] == 1987:
        TmWin[i] = 12
    elif stats['Tm'][i] == 'LAC' and stats['Year'][i] == 1988:
        TmWin[i] = 17
    elif stats['Tm'][i] == 'LAC' and stats['Year'][i] == 1989:
        TmWin[i] = 21
    elif stats['Tm'][i] == 'LAC' and stats['Year'][i] == 1990:
        TmWin[i] = 30
    elif stats['Tm'][i] == 'LAC' and stats['Year'][i] == 1991:
        TmWin[i] = 31
    elif stats['Tm'][i] == 'LAC' and stats['Year'][i] == 1992:
        TmWin[i] = 45
    elif stats['Tm'][i] == 'LAC' and stats['Year'][i] == 1993:
        TmWin[i] = 41
    elif stats['Tm'][i] == 'LAC' and stats['Year'][i] == 1994:
        TmWin[i] = 27
    elif stats['Tm'][i] == 'LAC' and stats['Year'][i] == 1995:
        TmWin[i] = 17
    elif stats['Tm'][i] == 'LAC' and stats['Year'][i] == 1996:
        TmWin[i] = 29
    elif stats['Tm'][i] == 'LAC' and stats['Year'][i] == 1997:
        TmWin[i] = 36
    elif stats['Tm'][i] == 'LAC' and stats['Year'][i] == 1998:
        TmWin[i] = 17
    elif stats['Tm'][i] == 'LAC' and stats['Year'][i] == 1999:
        TmWin[i] = 9
    elif stats['Tm'][i] == 'LAC' and stats['Year'][i] == 2000:
        TmWin[i] = 15
    elif stats['Tm'][i] == 'LAC' and stats['Year'][i] == 2001:
        TmWin[i] = 31
    elif stats['Tm'][i] == 'LAC' and stats['Year'][i] == 2002:
        TmWin[i] = 39
    elif stats['Tm'][i] == 'LAC' and stats['Year'][i] == 2003:
        TmWin[i] = 27
    elif stats['Tm'][i] == 'LAC' and stats['Year'][i] == 2004:
        TmWin[i] = 28
    elif stats['Tm'][i] == 'LAC' and stats['Year'][i] == 2005:
        TmWin[i] = 37
    elif stats['Tm'][i] == 'LAC' and stats['Year'][i] == 2006:
        TmWin[i] = 47
    elif stats['Tm'][i] == 'LAC' and stats['Year'][i] == 2007:
        TmWin[i] = 40
    elif stats['Tm'][i] == 'LAC' and stats['Year'][i] == 2008:
        TmWin[i] = 23
    elif stats['Tm'][i] == 'LAC' and stats['Year'][i] == 2009:
        TmWin[i] = 19
    elif stats['Tm'][i] == 'LAC' and stats['Year'][i] == 2010:
        TmWin[i] = 29
    elif stats['Tm'][i] == 'LAC' and stats['Year'][i] == 2011:
        TmWin[i] = 32
    elif stats['Tm'][i] == 'LAC' and stats['Year'][i] == 2012:
        TmWin[i] = 40
    elif stats['Tm'][i] == 'LAC' and stats['Year'][i] == 2013:
        TmWin[i] = 56
    elif stats['Tm'][i] == 'LAC' and stats['Year'][i] == 2014:
        TmWin[i] = 57
    elif stats['Tm'][i] == 'LAC' and stats['Year'][i] == 2015:
        TmWin[i] = 56
    elif stats['Tm'][i] == 'LAC' and stats['Year'][i] == 2016:
        TmWin[i] = 53
    elif stats['Tm'][i] == 'LAC' and stats['Year'][i] == 2017:
        TmWin[i] = 51
    elif stats['Tm'][i] == 'LAC' and stats['Year'][i] == 2018:
        TmWin[i] = 42
    elif stats['Tm'][i] == 'LAC' and stats['Year'][i] == 2019:
        TmWin[i] = 48
    
    # For Sac Kings
    elif stats['Tm'][i] == 'SAC' and stats['Year'][i] == 1986:
        TmWin[i] = 37
    elif stats['Tm'][i] == 'SAC' and stats['Year'][i] == 1987:
        TmWin[i] = 29
    elif stats['Tm'][i] == 'SAC' and stats['Year'][i] == 1988:
        TmWin[i] = 24
    elif stats['Tm'][i] == 'SAC' and stats['Year'][i] == 1989:
        TmWin[i] = 27
    elif stats['Tm'][i] == 'SAC' and stats['Year'][i] == 1990:
        TmWin[i] = 23
    elif stats['Tm'][i] == 'SAC' and stats['Year'][i] == 1991:
        TmWin[i] = 25
    elif stats['Tm'][i] == 'SAC' and stats['Year'][i] == 1992:
        TmWin[i] = 29
    elif stats['Tm'][i] == 'SAC' and stats['Year'][i] == 1993:
        TmWin[i] = 25
    elif stats['Tm'][i] == 'SAC' and stats['Year'][i] == 1994:
        TmWin[i] = 28
    elif stats['Tm'][i] == 'SAC' and stats['Year'][i] == 1995:
        TmWin[i] = 39
    elif stats['Tm'][i] == 'SAC' and stats['Year'][i] == 1996:
        TmWin[i] = 39
    elif stats['Tm'][i] == 'SAC' and stats['Year'][i] == 1997:
        TmWin[i] = 34
    elif stats['Tm'][i] == 'SAC' and stats['Year'][i] == 1998:
        TmWin[i] = 27
    elif stats['Tm'][i] == 'SAC' and stats['Year'][i] == 1999:
        TmWin[i] = 27
    elif stats['Tm'][i] == 'SAC' and stats['Year'][i] == 2000:
        TmWin[i] = 44
    elif stats['Tm'][i] == 'SAC' and stats['Year'][i] == 2001:
        TmWin[i] = 55
    elif stats['Tm'][i] == 'SAC' and stats['Year'][i] == 2002:
        TmWin[i] = 61
    elif stats['Tm'][i] == 'SAC' and stats['Year'][i] == 2003:
        TmWin[i] = 59
    elif stats['Tm'][i] == 'SAC' and stats['Year'][i] == 2004:
        TmWin[i] = 55
    elif stats['Tm'][i] == 'SAC' and stats['Year'][i] == 2005:
        TmWin[i] = 50
    elif stats['Tm'][i] == 'SAC' and stats['Year'][i] == 2006:
        TmWin[i] = 44
    elif stats['Tm'][i] == 'SAC' and stats['Year'][i] == 2007:
        TmWin[i] = 33
    elif stats['Tm'][i] == 'SAC' and stats['Year'][i] == 2008:
        TmWin[i] = 38
    elif stats['Tm'][i] == 'SAC' and stats['Year'][i] == 2009:
        TmWin[i] = 17
    elif stats['Tm'][i] == 'SAC' and stats['Year'][i] == 2010:
        TmWin[i] = 25
    elif stats['Tm'][i] == 'SAC' and stats['Year'][i] == 2011:
        TmWin[i] = 24
    elif stats['Tm'][i] == 'SAC' and stats['Year'][i] == 2012:
        TmWin[i] = 22
    elif stats['Tm'][i] == 'SAC' and stats['Year'][i] == 2013:
        TmWin[i] = 28
    elif stats['Tm'][i] == 'SAC' and stats['Year'][i] == 2014:
        TmWin[i] = 28
    elif stats['Tm'][i] == 'SAC' and stats['Year'][i] == 2015:
        TmWin[i] = 29
    elif stats['Tm'][i] == 'SAC' and stats['Year'][i] == 2016:
        TmWin[i] = 33
    elif stats['Tm'][i] == 'SAC' and stats['Year'][i] == 2017:
        TmWin[i] = 32
    elif stats['Tm'][i] == 'SAC' and stats['Year'][i] == 2018:
        TmWin[i] = 27
    elif stats['Tm'][i] == 'SAC' and stats['Year'][i] == 2019:
        TmWin[i] = 39
    
    # For Heat
    elif stats['Tm'][i] == 'MIA' and stats['Year'][i] == 1989:
        TmWin[i] = 15
    elif stats['Tm'][i] == 'MIA' and stats['Year'][i] == 1990:
        TmWin[i] = 18
    elif stats['Tm'][i] == 'MIA' and stats['Year'][i] == 1991:
        TmWin[i] = 24
    elif stats['Tm'][i] == 'MIA' and stats['Year'][i] == 1992:
        TmWin[i] = 38
    elif stats['Tm'][i] == 'MIA' and stats['Year'][i] == 1993:
        TmWin[i] = 36
    elif stats['Tm'][i] == 'MIA' and stats['Year'][i] == 1994:
        TmWin[i] = 42
    elif stats['Tm'][i] == 'MIA' and stats['Year'][i] == 1995:
        TmWin[i] = 32
    elif stats['Tm'][i] == 'MIA' and stats['Year'][i] == 1996:
        TmWin[i] = 42
    elif stats['Tm'][i] == 'MIA' and stats['Year'][i] == 1997:
        TmWin[i] = 61
    elif stats['Tm'][i] == 'MIA' and stats['Year'][i] == 1998:
        TmWin[i] = 55
    elif stats['Tm'][i] == 'MIA' and stats['Year'][i] == 1999:
        TmWin[i] = 33
    elif stats['Tm'][i] == 'MIA' and stats['Year'][i] == 2000:
        TmWin[i] = 52
    elif stats['Tm'][i] == 'MIA' and stats['Year'][i] == 2001:
        TmWin[i] = 50
    elif stats['Tm'][i] == 'MIA' and stats['Year'][i] == 2002:
        TmWin[i] = 36
    elif stats['Tm'][i] == 'MIA' and stats['Year'][i] == 2003:
        TmWin[i] = 25
    elif stats['Tm'][i] == 'MIA' and stats['Year'][i] == 2004:
        TmWin[i] = 42
    elif stats['Tm'][i] == 'MIA' and stats['Year'][i] == 2005:
        TmWin[i] = 59
    elif stats['Tm'][i] == 'MIA' and stats['Year'][i] == 2006:
        TmWin[i] = 52
    elif stats['Tm'][i] == 'MIA' and stats['Year'][i] == 2007:
        TmWin[i] = 44
    elif stats['Tm'][i] == 'MIA' and stats['Year'][i] == 2008:
        TmWin[i] = 15
    elif stats['Tm'][i] == 'MIA' and stats['Year'][i] == 2009:
        TmWin[i] = 43
    elif stats['Tm'][i] == 'MIA' and stats['Year'][i] == 2010:
        TmWin[i] = 47
    elif stats['Tm'][i] == 'MIA' and stats['Year'][i] == 2011:
        TmWin[i] = 58
    elif stats['Tm'][i] == 'MIA' and stats['Year'][i] == 2012:
        TmWin[i] = 46
    elif stats['Tm'][i] == 'MIA' and stats['Year'][i] == 2013:
        TmWin[i] = 66
    elif stats['Tm'][i] == 'MIA' and stats['Year'][i] == 2014:
        TmWin[i] = 54
    elif stats['Tm'][i] == 'MIA' and stats['Year'][i] == 2015:
        TmWin[i] = 37
    elif stats['Tm'][i] == 'MIA' and stats['Year'][i] == 2016:
        TmWin[i] = 48
    elif stats['Tm'][i] == 'MIA' and stats['Year'][i] == 2017:
        TmWin[i] = 41
    elif stats['Tm'][i] == 'MIA' and stats['Year'][i] == 2018:
        TmWin[i] = 44
    elif stats['Tm'][i] == 'MIA' and stats['Year'][i] == 2019:
        TmWin[i] = 39
    
    # For Magic
    elif stats['Tm'][i] == 'ORL' and stats['Year'][i] == 1990:
        TmWin[i] = 18
    elif stats['Tm'][i] == 'ORL' and stats['Year'][i] == 1991:
        TmWin[i] = 31
    elif stats['Tm'][i] == 'ORL' and stats['Year'][i] == 1992:
        TmWin[i] = 21
    elif stats['Tm'][i] == 'ORL' and stats['Year'][i] == 1993:
        TmWin[i] = 41
    elif stats['Tm'][i] == 'ORL' and stats['Year'][i] == 1994:
        TmWin[i] = 50
    elif stats['Tm'][i] == 'ORL' and stats['Year'][i] == 1995:
        TmWin[i] = 57
    elif stats['Tm'][i] == 'ORL' and stats['Year'][i] == 1996:
        TmWin[i] = 60
    elif stats['Tm'][i] == 'ORL' and stats['Year'][i] == 1997:
        TmWin[i] = 45
    elif stats['Tm'][i] == 'ORL' and stats['Year'][i] == 1998:
        TmWin[i] = 41
    elif stats['Tm'][i] == 'ORL' and stats['Year'][i] == 1999:
        TmWin[i] = 33
    elif stats['Tm'][i] == 'ORL' and stats['Year'][i] == 2000:
        TmWin[i] = 41
    elif stats['Tm'][i] == 'ORL' and stats['Year'][i] == 2001:
        TmWin[i] = 43
    elif stats['Tm'][i] == 'ORL' and stats['Year'][i] == 2002:
        TmWin[i] = 44
    elif stats['Tm'][i] == 'ORL' and stats['Year'][i] == 2003:
        TmWin[i] = 42
    elif stats['Tm'][i] == 'ORL' and stats['Year'][i] == 2004:
        TmWin[i] = 21
    elif stats['Tm'][i] == 'ORL' and stats['Year'][i] == 2005:
        TmWin[i] = 36
    elif stats['Tm'][i] == 'ORL' and stats['Year'][i] == 2006:
        TmWin[i] = 36
    elif stats['Tm'][i] == 'ORL' and stats['Year'][i] == 2007:
        TmWin[i] = 40
    elif stats['Tm'][i] == 'ORL' and stats['Year'][i] == 2008:
        TmWin[i] = 52
    elif stats['Tm'][i] == 'ORL' and stats['Year'][i] == 2009:
        TmWin[i] = 59
    elif stats['Tm'][i] == 'ORL' and stats['Year'][i] == 2010:
        TmWin[i] = 59
    elif stats['Tm'][i] == 'ORL' and stats['Year'][i] == 2011:
        TmWin[i] = 52
    elif stats['Tm'][i] == 'ORL' and stats['Year'][i] == 2012:
        TmWin[i] = 37
    elif stats['Tm'][i] == 'ORL' and stats['Year'][i] == 2013:
        TmWin[i] = 20
    elif stats['Tm'][i] == 'ORL' and stats['Year'][i] == 2014:
        TmWin[i] = 23
    elif stats['Tm'][i] == 'ORL' and stats['Year'][i] == 2015:
        TmWin[i] = 25
    elif stats['Tm'][i] == 'ORL' and stats['Year'][i] == 2016:
        TmWin[i] = 35
    elif stats['Tm'][i] == 'ORL' and stats['Year'][i] == 2017:
        TmWin[i] = 29
    elif stats['Tm'][i] == 'ORL' and stats['Year'][i] == 2018:
        TmWin[i] = 25
    elif stats['Tm'][i] == 'ORL' and stats['Year'][i] == 2019:
        TmWin[i] = 42
    
    # For Timberwolves 
    elif stats['Tm'][i] == 'MIN' and stats['Year'][i] == 1990:
        TmWin[i] = 22
    elif stats['Tm'][i] == 'MIN' and stats['Year'][i] == 1991:
        TmWin[i] = 29
    elif stats['Tm'][i] == 'MIN' and stats['Year'][i] == 1992:
        TmWin[i] = 15
    elif stats['Tm'][i] == 'MIN' and stats['Year'][i] == 1993:
        TmWin[i] = 19
    elif stats['Tm'][i] == 'MIN' and stats['Year'][i] == 1994:
        TmWin[i] = 20
    elif stats['Tm'][i] == 'MIN' and stats['Year'][i] == 1995:
        TmWin[i] = 21
    elif stats['Tm'][i] == 'MIN' and stats['Year'][i] == 1996:
        TmWin[i] = 26
    elif stats['Tm'][i] == 'MIN' and stats['Year'][i] == 1997:
        TmWin[i] = 40
    elif stats['Tm'][i] == 'MIN' and stats['Year'][i] == 1998:
        TmWin[i] = 45
    elif stats['Tm'][i] == 'MIN' and stats['Year'][i] == 1999:
        TmWin[i] = 25
    elif stats['Tm'][i] == 'MIN' and stats['Year'][i] == 2000:
        TmWin[i] = 50
    elif stats['Tm'][i] == 'MIN' and stats['Year'][i] == 2001:
        TmWin[i] = 47
    elif stats['Tm'][i] == 'MIN' and stats['Year'][i] == 2002:
        TmWin[i] = 50
    elif stats['Tm'][i] == 'MIN' and stats['Year'][i] == 2003:
        TmWin[i] = 51
    elif stats['Tm'][i] == 'MIN' and stats['Year'][i] == 2004:
        TmWin[i] = 58
    elif stats['Tm'][i] == 'MIN' and stats['Year'][i] == 2005:
        TmWin[i] = 44
    elif stats['Tm'][i] == 'MIN' and stats['Year'][i] == 2006:
        TmWin[i] = 33
    elif stats['Tm'][i] == 'MIN' and stats['Year'][i] == 2007:
        TmWin[i] = 32
    elif stats['Tm'][i] == 'MIN' and stats['Year'][i] == 2008:
        TmWin[i] = 22
    elif stats['Tm'][i] == 'MIN' and stats['Year'][i] == 2009:
        TmWin[i] = 24
    elif stats['Tm'][i] == 'MIN' and stats['Year'][i] == 2010:
        TmWin[i] = 15
    elif stats['Tm'][i] == 'MIN' and stats['Year'][i] == 2011:
        TmWin[i] = 17
    elif stats['Tm'][i] == 'MIN' and stats['Year'][i] == 2012:
        TmWin[i] = 26
    elif stats['Tm'][i] == 'MIN' and stats['Year'][i] == 2013:
        TmWin[i] = 31
    elif stats['Tm'][i] == 'MIN' and stats['Year'][i] == 2014:
        TmWin[i] = 40
    elif stats['Tm'][i] == 'MIN' and stats['Year'][i] == 2015:
        TmWin[i] = 16
    elif stats['Tm'][i] == 'MIN' and stats['Year'][i] == 2016:
        TmWin[i] = 29
    elif stats['Tm'][i] == 'MIN' and stats['Year'][i] == 2017:
        TmWin[i] = 31
    elif stats['Tm'][i] == 'MIN' and stats['Year'][i] == 2018:
        TmWin[i] = 47
    elif stats['Tm'][i] == 'MIN' and stats['Year'][i] == 2019:
        TmWin[i] = 36
    
    # For Raptors
    elif stats['Tm'][i] == 'TOR' and stats['Year'][i] == 1996:
        TmWin[i] = 21
    elif stats['Tm'][i] == 'TOR' and stats['Year'][i] == 1997:
        TmWin[i] = 30
    elif stats['Tm'][i] == 'TOR' and stats['Year'][i] == 1998:
        TmWin[i] = 16
    elif stats['Tm'][i] == 'TOR' and stats['Year'][i] == 1999:
        TmWin[i] = 23
    elif stats['Tm'][i] == 'TOR' and stats['Year'][i] == 2000:
        TmWin[i] = 45
    elif stats['Tm'][i] == 'TOR' and stats['Year'][i] == 2001:
        TmWin[i] = 47
    elif stats['Tm'][i] == 'TOR' and stats['Year'][i] == 2002:
        TmWin[i] = 42
    elif stats['Tm'][i] == 'TOR' and stats['Year'][i] == 2003:
        TmWin[i] = 24
    elif stats['Tm'][i] == 'TOR' and stats['Year'][i] == 2004:
        TmWin[i] = 33
    elif stats['Tm'][i] == 'TOR' and stats['Year'][i] == 2005:
        TmWin[i] = 33
    elif stats['Tm'][i] == 'TOR' and stats['Year'][i] == 2006:
        TmWin[i] = 27
    elif stats['Tm'][i] == 'TOR' and stats['Year'][i] == 2007:
        TmWin[i] = 47
    elif stats['Tm'][i] == 'TOR' and stats['Year'][i] == 2008:
        TmWin[i] = 41
    elif stats['Tm'][i] == 'TOR' and stats['Year'][i] == 2009:
        TmWin[i] = 33
    elif stats['Tm'][i] == 'TOR' and stats['Year'][i] == 2010:
        TmWin[i] = 40
    elif stats['Tm'][i] == 'TOR' and stats['Year'][i] == 2011:
        TmWin[i] = 22
    elif stats['Tm'][i] == 'TOR' and stats['Year'][i] == 2012:
        TmWin[i] = 23
    elif stats['Tm'][i] == 'TOR' and stats['Year'][i] == 2013:
        TmWin[i] = 34
    elif stats['Tm'][i] == 'TOR' and stats['Year'][i] == 2014:
        TmWin[i] = 48
    elif stats['Tm'][i] == 'TOR' and stats['Year'][i] == 2015:
        TmWin[i] = 49
    elif stats['Tm'][i] == 'TOR' and stats['Year'][i] == 2016:
        TmWin[i] = 56
    elif stats['Tm'][i] == 'TOR' and stats['Year'][i] == 2017:
        TmWin[i] = 51
    elif stats['Tm'][i] == 'TOR' and stats['Year'][i] == 2018:
        TmWin[i] = 59
    elif stats['Tm'][i] == 'TOR' and stats['Year'][i] == 2019:
        TmWin[i] = 58
    
    # For wash the wizards
    elif stats['Tm'][i] == 'WAS' and stats['Year'][i] == 1998:
        TmWin[i] = 42
    elif stats['Tm'][i] == 'WAS' and stats['Year'][i] == 1999:
        TmWin[i] = 18
    elif stats['Tm'][i] == 'WAS' and stats['Year'][i] == 2000:
        TmWin[i] = 29
    elif stats['Tm'][i] == 'WAS' and stats['Year'][i] == 2001:
        TmWin[i] = 19
    elif stats['Tm'][i] == 'WAS' and stats['Year'][i] == 2002:
        TmWin[i] = 37
    elif stats['Tm'][i] == 'WAS' and stats['Year'][i] == 2003:
        TmWin[i] = 37
    elif stats['Tm'][i] == 'WAS' and stats['Year'][i] == 2004:
        TmWin[i] = 25
    elif stats['Tm'][i] == 'WAS' and stats['Year'][i] == 2005:
        TmWin[i] = 45
    elif stats['Tm'][i] == 'WAS' and stats['Year'][i] == 2006:
        TmWin[i] = 42
    elif stats['Tm'][i] == 'WAS' and stats['Year'][i] == 2007:
        TmWin[i] = 41
    elif stats['Tm'][i] == 'WAS' and stats['Year'][i] == 2008:
        TmWin[i] = 43
    elif stats['Tm'][i] == 'WAS' and stats['Year'][i] == 2009:
        TmWin[i] = 19
    elif stats['Tm'][i] == 'WAS' and stats['Year'][i] == 2010:
        TmWin[i] = 26
    elif stats['Tm'][i] == 'WAS' and stats['Year'][i] == 2011:
        TmWin[i] = 23
    elif stats['Tm'][i] == 'WAS' and stats['Year'][i] == 2012:
        TmWin[i] = 20
    elif stats['Tm'][i] == 'WAS' and stats['Year'][i] == 2013:
        TmWin[i] = 29
    elif stats['Tm'][i] == 'WAS' and stats['Year'][i] == 2014:
        TmWin[i] = 44
    elif stats['Tm'][i] == 'WAS' and stats['Year'][i] == 2015:
        TmWin[i] = 46
    elif stats['Tm'][i] == 'WAS' and stats['Year'][i] == 2016:
        TmWin[i] = 41
    elif stats['Tm'][i] == 'WAS' and stats['Year'][i] == 2017:
        TmWin[i] = 49
    elif stats['Tm'][i] == 'WAS' and stats['Year'][i] == 2018:
        TmWin[i] = 43
    elif stats['Tm'][i] == 'WAS' and stats['Year'][i] == 2019:
        TmWin[i] = 32
    
    # For Memphis Grizzlies
    elif stats['Tm'][i] == 'MEM' and stats['Year'][i] == 2002:
        TmWin[i] = 23
    elif stats['Tm'][i] == 'MEM' and stats['Year'][i] == 2003:
        TmWin[i] = 28
    elif stats['Tm'][i] == 'MEM' and stats['Year'][i] == 2004:
        TmWin[i] = 50
    elif stats['Tm'][i] == 'MEM' and stats['Year'][i] == 2005:
        TmWin[i] = 45
    elif stats['Tm'][i] == 'MEM' and stats['Year'][i] == 2006:
        TmWin[i] = 49
    elif stats['Tm'][i] == 'MEM' and stats['Year'][i] == 2007:
        TmWin[i] = 22
    elif stats['Tm'][i] == 'MEM' and stats['Year'][i] == 2008:
        TmWin[i] = 22
    elif stats['Tm'][i] == 'MEM' and stats['Year'][i] == 2009:
        TmWin[i] = 24
    elif stats['Tm'][i] == 'MEM' and stats['Year'][i] == 2010:
        TmWin[i] = 40
    elif stats['Tm'][i] == 'MEM' and stats['Year'][i] == 2011:
        TmWin[i] = 46
    elif stats['Tm'][i] == 'MEM' and stats['Year'][i] == 2012:
        TmWin[i] = 41
    elif stats['Tm'][i] == 'MEM' and stats['Year'][i] == 2013:
        TmWin[i] = 56
    elif stats['Tm'][i] == 'MEM' and stats['Year'][i] == 2014:
        TmWin[i] = 50
    elif stats['Tm'][i] == 'MEM' and stats['Year'][i] == 2015:
        TmWin[i] = 55
    elif stats['Tm'][i] == 'MEM' and stats['Year'][i] == 2016:
        TmWin[i] = 42
    elif stats['Tm'][i] == 'MEM' and stats['Year'][i] == 2017:
        TmWin[i] = 43
    elif stats['Tm'][i] == 'MEM' and stats['Year'][i] == 2018:
        TmWin[i] = 22
    elif stats['Tm'][i] == 'MEM' and stats['Year'][i] == 2019:
        TmWin[i] = 33
    
    # For NO Hornets
    elif stats['Tm'][i] == 'NOH' and stats['Year'][i] == 2003:
        TmWin[i] = 47
    elif stats['Tm'][i] == 'NOH' and stats['Year'][i] == 2004:
        TmWin[i] = 41
    elif stats['Tm'][i] == 'NOH' and stats['Year'][i] == 2005:
        TmWin[i] = 18
    elif stats['Tm'][i] == 'NOH' and stats['Year'][i] == 2006:
        TmWin[i] = 38
    elif stats['Tm'][i] == 'NOH' and stats['Year'][i] == 2007:
        TmWin[i] = 39
    elif stats['Tm'][i] == 'NOH' and stats['Year'][i] == 2008:
        TmWin[i] = 56
    elif stats['Tm'][i] == 'NOH' and stats['Year'][i] == 2009:
        TmWin[i] = 49
    elif stats['Tm'][i] == 'NOH' and stats['Year'][i] == 2010:
        TmWin[i] = 37
    elif stats['Tm'][i] == 'NOH' and stats['Year'][i] == 2011:
        TmWin[i] = 46
    elif stats['Tm'][i] == 'NOH' and stats['Year'][i] == 2012:
        TmWin[i] = 21
    elif stats['Tm'][i] == 'NOH' and stats['Year'][i] == 2013:
        TmWin[i] = 27
    
    # For Charlotte Bobcats
    elif stats['Tm'][i] == 'CHA' and stats['Year'][i] == 2005:
        TmWin[i] = 18
    elif stats['Tm'][i] == 'CHA' and stats['Year'][i] == 2006:
        TmWin[i] = 26
    elif stats['Tm'][i] == 'CHA' and stats['Year'][i] == 2007:
        TmWin[i] = 33
    elif stats['Tm'][i] == 'CHA' and stats['Year'][i] == 2008:
        TmWin[i] = 32
    elif stats['Tm'][i] == 'CHA' and stats['Year'][i] == 2009:
        TmWin[i] = 35
    elif stats['Tm'][i] == 'CHA' and stats['Year'][i] == 2010:
        TmWin[i] = 44
    elif stats['Tm'][i] == 'CHA' and stats['Year'][i] == 2011:
        TmWin[i] = 34
    elif stats['Tm'][i] == 'CHA' and stats['Year'][i] == 2012:
        TmWin[i] = 7
    elif stats['Tm'][i] == 'CHA' and stats['Year'][i] == 2013:
        TmWin[i] = 21
    elif stats['Tm'][i] == 'CHA' and stats['Year'][i] == 2014:
        TmWin[i] = 43
    
    # NOK
    elif stats['Tm'][i] == 'NOK' and stats['Year'][i] == 2006:
        TmWin[i] = 38
    elif stats['Tm'][i] == 'NOK' and stats['Year'][i] == 2007:
        TmWin[i] = 39
    
    
    # For OKC
    elif stats['Tm'][i] == 'OKC' and stats['Year'][i] == 2009:
        TmWin[i] = 23
    elif stats['Tm'][i] == 'OKC' and stats['Year'][i] == 2010:
        TmWin[i] = 50
    elif stats['Tm'][i] == 'OKC' and stats['Year'][i] == 2011:
        TmWin[i] = 55
    elif stats['Tm'][i] == 'OKC' and stats['Year'][i] == 2012:
        TmWin[i] = 47
    elif stats['Tm'][i] == 'OKC' and stats['Year'][i] == 2013:
        TmWin[i] = 60
    elif stats['Tm'][i] == 'OKC' and stats['Year'][i] == 2014:
        TmWin[i] = 59
    elif stats['Tm'][i] == 'OKC' and stats['Year'][i] == 2015:
        TmWin[i] = 45
    elif stats['Tm'][i] == 'OKC' and stats['Year'][i] == 2016:
        TmWin[i] = 55
    elif stats['Tm'][i] == 'OKC' and stats['Year'][i] == 2017:
        TmWin[i] = 47
    elif stats['Tm'][i] == 'OKC' and stats['Year'][i] == 2018:
        TmWin[i] = 48
    elif stats['Tm'][i] == 'OKC' and stats['Year'][i] == 2019:
        TmWin[i] = 49
    
    # For Brooklyn Nets
    elif stats['Tm'][i] == 'BRK' and stats['Year'][i] == 2013:
        TmWin[i] = 49
    elif stats['Tm'][i] == 'BRK' and stats['Year'][i] == 2014:
        TmWin[i] = 44
    elif stats['Tm'][i] == 'BRK' and stats['Year'][i] == 2015:
        TmWin[i] = 38
    elif stats['Tm'][i] == 'BRK' and stats['Year'][i] == 2016:
        TmWin[i] = 21
    elif stats['Tm'][i] == 'BRK' and stats['Year'][i] == 2017:
        TmWin[i] = 20
    elif stats['Tm'][i] == 'BRK' and stats['Year'][i] == 2018:
        TmWin[i] = 28
    elif stats['Tm'][i] == 'BRK' and stats['Year'][i] == 2019:
        TmWin[i] = 42
    
    # For NO Pelicans
    elif stats['Tm'][i] == 'NOP' and stats['Year'][i] == 2014:
        TmWin[i] = 34
    elif stats['Tm'][i] == 'NOP' and stats['Year'][i] == 2015:
        TmWin[i] = 45
    elif stats['Tm'][i] == 'NOP' and stats['Year'][i] == 2016:
        TmWin[i] = 30
    elif stats['Tm'][i] == 'NOP' and stats['Year'][i] == 2017:
        TmWin[i] = 34
    elif stats['Tm'][i] == 'NOP' and stats['Year'][i] == 2018:
        TmWin[i] = 48
    elif stats['Tm'][i] == 'NOP' and stats['Year'][i] == 2019:
        TmWin[i] = 33
    
    # For Charlotte Hornets
    elif stats['Tm'][i] == 'CHO' and stats['Year'][i] == 2015:
        TmWin[i] = 33
    elif stats['Tm'][i] == 'CHO' and stats['Year'][i] == 2016:
        TmWin[i] = 48
    elif stats['Tm'][i] == 'CHO' and stats['Year'][i] == 2017:
        TmWin[i] = 36
    elif stats['Tm'][i] == 'CHO' and stats['Year'][i] == 2018:
        TmWin[i] = 36
    elif stats['Tm'][i] == 'CHO' and stats['Year'][i] == 2019:
        TmWin[i] = 39
    
    # For KCK
    elif stats['Tm'][i] == 'KCK' and stats['Year'][i] == 1978:
        TmWin[i] = 31
    elif stats['Tm'][i] == 'KCK' and stats['Year'][i] == 1979:
        TmWin[i] = 48
    elif stats['Tm'][i] == 'KCK' and stats['Year'][i] == 1980:
        TmWin[i] = 47
    elif stats['Tm'][i] == 'KCK' and stats['Year'][i] == 1981:
        TmWin[i] = 40
    elif stats['Tm'][i] == 'KCK' and stats['Year'][i] == 1982:
        TmWin[i] = 30
    elif stats['Tm'][i] == 'KCK' and stats['Year'][i] == 1983:
        TmWin[i] = 45
    elif stats['Tm'][i] == 'KCK' and stats['Year'][i] == 1984:
        TmWin[i] = 38
    elif stats['Tm'][i] == 'KCK' and stats['Year'][i] == 1985:
        TmWin[i] = 31
    
    # For New Jersey Nets
    elif stats['Tm'][i] == 'NJN' and stats['Year'][i] == 1978:
        TmWin[i] = 24
    elif stats['Tm'][i] == 'NJN' and stats['Year'][i] == 1979:
        TmWin[i] = 37
    elif stats['Tm'][i] == 'NJN' and stats['Year'][i] == 1980:
        TmWin[i] = 34
    elif stats['Tm'][i] == 'NJN' and stats['Year'][i] == 1981:
        TmWin[i] = 24
    elif stats['Tm'][i] == 'NJN' and stats['Year'][i] == 1982:
        TmWin[i] = 44
    elif stats['Tm'][i] == 'NJN' and stats['Year'][i] == 1983:
        TmWin[i] = 49
    elif stats['Tm'][i] == 'NJN' and stats['Year'][i] == 1984:
        TmWin[i] = 45
    elif stats['Tm'][i] == 'NJN' and stats['Year'][i] == 1985:
        TmWin[i] = 42
    elif stats['Tm'][i] == 'NJN' and stats['Year'][i] == 1986:
        TmWin[i] = 39
    elif stats['Tm'][i] == 'NJN' and stats['Year'][i] == 1987:
        TmWin[i] = 24
    elif stats['Tm'][i] == 'NJN' and stats['Year'][i] == 1988:
        TmWin[i] = 19
    elif stats['Tm'][i] == 'NJN' and stats['Year'][i] == 1989:
        TmWin[i] = 26
    elif stats['Tm'][i] == 'NJN' and stats['Year'][i] == 1990:
        TmWin[i] = 40
    elif stats['Tm'][i] == 'NJN' and stats['Year'][i] == 1991:
        TmWin[i] = 43
    elif stats['Tm'][i] == 'NJN' and stats['Year'][i] == 1992:
        TmWin[i] = 45
    elif stats['Tm'][i] == 'NJN' and stats['Year'][i] == 1993:
        TmWin[i] = 30
    elif stats['Tm'][i] == 'NJN' and stats['Year'][i] == 1994:
        TmWin[i] = 30
    elif stats['Tm'][i] == 'NJN' and stats['Year'][i] == 1995:
        TmWin[i] = 26
    elif stats['Tm'][i] == 'NJN' and stats['Year'][i] == 1996:
        TmWin[i] = 43
    elif stats['Tm'][i] == 'NJN' and stats['Year'][i] == 1997:
        TmWin[i] = 16
    elif stats['Tm'][i] == 'NJN' and stats['Year'][i] == 1998:
        TmWin[i] = 31
    elif stats['Tm'][i] == 'NJN' and stats['Year'][i] == 1999:
        TmWin[i] = 26
    elif stats['Tm'][i] == 'NJN' and stats['Year'][i] == 2000:
        TmWin[i] = 52
    elif stats['Tm'][i] == 'NJN' and stats['Year'][i] == 2001:
        TmWin[i] = 49
    elif stats['Tm'][i] == 'NJN' and stats['Year'][i] == 2002:
        TmWin[i] = 47
    elif stats['Tm'][i] == 'NJN' and stats['Year'][i] == 2003:
        TmWin[i] = 42
    elif stats['Tm'][i] == 'NJN' and stats['Year'][i] == 2004:
        TmWin[i] = 49
    elif stats['Tm'][i] == 'NJN' and stats['Year'][i] == 2005:
        TmWin[i] = 42
    elif stats['Tm'][i] == 'NJN' and stats['Year'][i] == 2006:
        TmWin[i] = 49
    elif stats['Tm'][i] == 'NJN' and stats['Year'][i] == 2007:
        TmWin[i] = 41
    elif stats['Tm'][i] == 'NJN' and stats['Year'][i] == 2008:
        TmWin[i] = 34
    elif stats['Tm'][i] == 'NJN' and stats['Year'][i] == 2009:
        TmWin[i] = 34
    elif stats['Tm'][i] == 'NJN' and stats['Year'][i] == 2010:
        TmWin[i] = 12
    elif stats['Tm'][i] == 'NJN' and stats['Year'][i] == 2011:
        TmWin[i] = 24
    elif stats['Tm'][i] == 'NJN' and stats['Year'][i] == 2012:
        TmWin[i] = 22
    
    # For Buffalo Braves
    elif stats['Tm'][i] == 'BUF' and stats['Year'][i] == 1978:
        TmWin[i] = 27
    
    # For NOJ
    elif stats['Tm'][i] == 'NOJ' and stats['Year'][i] == 1978:
        TmWin[i] = 39
    elif stats['Tm'][i] == 'NOJ' and stats['Year'][i] == 1978:
        TmWin[i] = 26
    
    # For Washington Bullets
    elif stats['Tm'][i] == 'WSB' and stats['Year'][i] == 1978:
        TmWin[i] = 44
    elif stats['Tm'][i] == 'WSB' and stats['Year'][i] == 1979:
        TmWin[i] = 54
    elif stats['Tm'][i] == 'WSB' and stats['Year'][i] == 1980:
        TmWin[i] = 39
    elif stats['Tm'][i] == 'WSB' and stats['Year'][i] == 1981:
        TmWin[i] = 39
    elif stats['Tm'][i] == 'WSB' and stats['Year'][i] == 1982:
        TmWin[i] = 43
    elif stats['Tm'][i] == 'WSB' and stats['Year'][i] == 1983:
        TmWin[i] = 42
    elif stats['Tm'][i] == 'WSB' and stats['Year'][i] == 1984:
        TmWin[i] = 35
    elif stats['Tm'][i] == 'WSB' and stats['Year'][i] == 1985:
        TmWin[i] = 40
    elif stats['Tm'][i] == 'WSB' and stats['Year'][i] == 1986:
        TmWin[i] = 39
    elif stats['Tm'][i] == 'WSB' and stats['Year'][i] == 1987:
        TmWin[i] = 42
    elif stats['Tm'][i] == 'WSB' and stats['Year'][i] == 1988:
        TmWin[i] = 38
    elif stats['Tm'][i] == 'WSB' and stats['Year'][i] == 1989:
        TmWin[i] = 40
    elif stats['Tm'][i] == 'WSB' and stats['Year'][i] == 1990:
        TmWin[i] = 31
    elif stats['Tm'][i] == 'WSB' and stats['Year'][i] == 1991:
        TmWin[i] = 30
    elif stats['Tm'][i] == 'WSB' and stats['Year'][i] == 1992:
        TmWin[i] = 25
    elif stats['Tm'][i] == 'WSB' and stats['Year'][i] == 1993:
        TmWin[i] = 22
    elif stats['Tm'][i] == 'WSB' and stats['Year'][i] == 1994:
        TmWin[i] = 24
    elif stats['Tm'][i] == 'WSB' and stats['Year'][i] == 1995:
        TmWin[i] = 21
    elif stats['Tm'][i] == 'WSB' and stats['Year'][i] == 1996:
        TmWin[i] = 39
    elif stats['Tm'][i] == 'WSB' and stats['Year'][i] == 1997:
        TmWin[i] = 44
   
    # For Seattle Supersonics
    elif stats['Tm'][i] == 'SEA' and stats['Year'][i] == 1978:
        TmWin[i] = 47
    elif stats['Tm'][i] == 'SEA' and stats['Year'][i] == 1979:
        TmWin[i] = 52
    elif stats['Tm'][i] == 'SEA' and stats['Year'][i] == 1980:
        TmWin[i] = 56
    elif stats['Tm'][i] == 'SEA' and stats['Year'][i] == 1981:
        TmWin[i] = 34
    elif stats['Tm'][i] == 'SEA' and stats['Year'][i] == 1982:
        TmWin[i] = 52
    elif stats['Tm'][i] == 'SEA' and stats['Year'][i] == 1983:
        TmWin[i] = 48
    elif stats['Tm'][i] == 'SEA' and stats['Year'][i] == 1984:
        TmWin[i] = 42
    elif stats['Tm'][i] == 'SEA' and stats['Year'][i] == 1985:
        TmWin[i] = 31
    elif stats['Tm'][i] == 'SEA' and stats['Year'][i] == 1986:
        TmWin[i] = 31
    elif stats['Tm'][i] == 'SEA' and stats['Year'][i] == 1987:
        TmWin[i] = 39
    elif stats['Tm'][i] == 'SEA' and stats['Year'][i] == 1988:
        TmWin[i] = 44
    elif stats['Tm'][i] == 'SEA' and stats['Year'][i] == 1989:
        TmWin[i] = 47
    elif stats['Tm'][i] == 'SEA' and stats['Year'][i] == 1990:
        TmWin[i] = 41
    elif stats['Tm'][i] == 'SEA' and stats['Year'][i] == 1991:
        TmWin[i] = 41
    elif stats['Tm'][i] == 'SEA' and stats['Year'][i] == 1992:
        TmWin[i] = 47
    elif stats['Tm'][i] == 'SEA' and stats['Year'][i] == 1993:
        TmWin[i] = 55
    elif stats['Tm'][i] == 'SEA' and stats['Year'][i] == 1994:
        TmWin[i] = 63
    elif stats['Tm'][i] == 'SEA' and stats['Year'][i] == 1995:
        TmWin[i] = 57
    elif stats['Tm'][i] == 'SEA' and stats['Year'][i] == 1996:
        TmWin[i] = 64
    elif stats['Tm'][i] == 'SEA' and stats['Year'][i] == 1997:
        TmWin[i] = 57
    elif stats['Tm'][i] == 'SEA' and stats['Year'][i] == 1998:
        TmWin[i] = 61
    elif stats['Tm'][i] == 'SEA' and stats['Year'][i] == 1999:
        TmWin[i] = 25
    elif stats['Tm'][i] == 'SEA' and stats['Year'][i] == 2000:
        TmWin[i] = 45
    elif stats['Tm'][i] == 'SEA' and stats['Year'][i] == 2001:
        TmWin[i] = 44
    elif stats['Tm'][i] == 'SEA' and stats['Year'][i] == 2002:
        TmWin[i] = 45
    elif stats['Tm'][i] == 'SEA' and stats['Year'][i] == 2003:
        TmWin[i] = 40
    elif stats['Tm'][i] == 'SEA' and stats['Year'][i] == 2004:
        TmWin[i] = 37
    elif stats['Tm'][i] == 'SEA' and stats['Year'][i] == 2005:
        TmWin[i] = 52
    elif stats['Tm'][i] == 'SEA' and stats['Year'][i] == 2006:
        TmWin[i] = 35
    elif stats['Tm'][i] == 'SEA' and stats['Year'][i] == 2007:
        TmWin[i] = 31
    elif stats['Tm'][i] == 'SEA' and stats['Year'][i] == 2008:
        TmWin[i] = 20
    
    # For San Diego Clippers SDC
    elif stats['Tm'][i] == 'SDC' and stats['Year'][i] == 1979:
        TmWin[i] = 43
    elif stats['Tm'][i] == 'SDC' and stats['Year'][i] == 1980:
        TmWin[i] = 35
    elif stats['Tm'][i] == 'SDC' and stats['Year'][i] == 1981:
        TmWin[i] = 36
    elif stats['Tm'][i] == 'SDC' and stats['Year'][i] == 1982:
        TmWin[i] = 17
    elif stats['Tm'][i] == 'SDC' and stats['Year'][i] == 1983:
        TmWin[i] = 25
    elif stats['Tm'][i] == 'SDC' and stats['Year'][i] == 1984:
        TmWin[i] = 30
    
    # For CHH Charlotte Hornets (FUCK YOU STOP CHANGING NAMES)
    elif stats['Tm'][i] == 'CHH' and stats['Year'][i] == 1989:
        TmWin[i] = 20
    elif stats['Tm'][i] == 'CHH' and stats['Year'][i] == 1990:
        TmWin[i] = 19
    elif stats['Tm'][i] == 'CHH' and stats['Year'][i] == 1991:
        TmWin[i] = 26
    elif stats['Tm'][i] == 'CHH' and stats['Year'][i] == 1992:
        TmWin[i] = 31
    elif stats['Tm'][i] == 'CHH' and stats['Year'][i] == 1993:
        TmWin[i] = 44
    elif stats['Tm'][i] == 'CHH' and stats['Year'][i] == 1994:
        TmWin[i] = 41
    elif stats['Tm'][i] == 'CHH' and stats['Year'][i] == 1995:
        TmWin[i] = 50
    elif stats['Tm'][i] == 'CHH' and stats['Year'][i] == 1996:
        TmWin[i] = 41
    elif stats['Tm'][i] == 'CHH' and stats['Year'][i] == 1997:
        TmWin[i] = 54
    elif stats['Tm'][i] == 'CHH' and stats['Year'][i] == 1998:
        TmWin[i] = 51
    elif stats['Tm'][i] == 'CHH' and stats['Year'][i] == 1999:
        TmWin[i] = 26
    elif stats['Tm'][i] == 'CHH' and stats['Year'][i] == 2000:
        TmWin[i] = 49
    elif stats['Tm'][i] == 'CHH' and stats['Year'][i] == 2001:
        TmWin[i] = 46
    elif stats['Tm'][i] == 'CHH' and stats['Year'][i] == 2002:
        TmWin[i] = 44
    
    # Vancouver Grizzlies
    elif stats['Tm'][i] == 'VAN' and stats['Year'][i] == 1996:
        TmWin[i] = 15
    elif stats['Tm'][i] == 'CHH' and stats['Year'][i] == 1997:
        TmWin[i] = 14
    elif stats['Tm'][i] == 'CHH' and stats['Year'][i] == 1998:
        TmWin[i] = 19
    elif stats['Tm'][i] == 'CHH' and stats['Year'][i] == 1999:
        TmWin[i] = 8
    elif stats['Tm'][i] == 'CHH' and stats['Year'][i] == 2000:
        TmWin[i] = 22
    else:
        TmWin[i] = 23

# %%
stats.insert(4, 'TmWin', TmWin)

# %%
stats[stats['Tm'] == 'SEA']
# Out:
#        Year            Player Pos  Age  TmWin   Tm   G    GS    MP   PER  \
# 49     1978        Fred Brown  SG   29     47  SEA  72   NaN  1965  19.6
# 116    1978        Al Fleming  SF   23     47  SEA  20   NaN    97  10.7
# 135    1978        Mike Green   C   26     47  SEA   9   NaN   250  14.2
# 147    1978       Joe Hassett  SG   22     47  SEA  48   NaN   404  11.9
# 169    1978   Dennis Johnson*  SG   23     47  SEA  81   NaN  2209  15.6
# 174    1978      John Johnson  SF   30     47  SEA  76   NaN  1812  11.9
# 295    1978       Bruce Seals  SF   24     47  SEA  73   NaN  1322  10.3
# 301    1978        Jack Sikma   C   22     47  SEA  82   NaN  2238  13.5
# 303    1978        Paul Silas  PF   34     47  SEA  82   NaN  2172  10.2
# 327    1978       Dean Tolson  PF   26     47  SEA   1   NaN     7  -7.1
# 337    1978      Wally Walker  SF   23     47  SEA  68   NaN  1003  12.5
# 348    1978       Slick Watts  PG   26     47  SEA  32   NaN   809   9.3
# ...

# %%
stats = stats[stats['Tm'] != 'TOT']

# %%
stats.to_csv(r'C:\Users\kengw\Desktop\stats_1.3.csv')
