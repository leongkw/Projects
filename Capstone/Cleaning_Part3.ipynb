# %%
import pandas as pd

# %%
stats = pd.read_csv('stats_1.3.csv')

# %%
stats = stats[stats['Tm'] != 'TOT']

# %%
stats.shape
# Out:
# (19152, 51)

# %%
stats.reset_index(drop=True, inplace=True)

# %%
stats.drop(labels='Unnamed: 0', axis=1, inplace=True)

# %%
stats.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19152 entries, 0 to 19151
# Data columns (total 51 columns):
# Year      19152 non-null int64
# Player    19152 non-null object
# Pos       19152 non-null object
# Age       19152 non-null int64
# TmWin     19152 non-null int64
# Tm        19152 non-null object
# G         19152 non-null int64
# GS        17876 non-null float64
# MP        19152 non-null int64
# PER       19152 non-null float64
# TS%       19152 non-null float64
# 3PAr      18420 non-null float64
# FTr       19060 non-null float64
# ORB%      19152 non-null float64
# DRB%      19152 non-null float64
# TRB%      19152 non-null float64
# AST%      19152 non-null float64
# STL%      19152 non-null float64
# BLK%      19152 non-null float64
# TOV%      19088 non-null float64
# USG%      19152 non-null float64
# OWS       19152 non-null float64
# DWS       19152 non-null float64
# WS        19152 non-null float64
# WS/48     19152 non-null float64
# ...

# %%
stats_player = stats.groupby(by=['Player', 'Year']).mean()

# %%
abc =stats_player.reset_index()

# %%
abc.head(100)
# Out:
#             Player  Year   Age      TmWin          G         GS      MP  \
# 0       A.C. Green  1986  22.0  62.000000  82.000000   1.000000  1542.0
# 1       A.C. Green  1987  23.0  65.000000  79.000000  72.000000  2240.0
# 2       A.C. Green  1988  24.0  62.000000  82.000000  64.000000  2636.0
# 3       A.C. Green  1989  25.0  57.000000  82.000000  82.000000  2510.0
# 4       A.C. Green  1990  26.0  63.000000  82.000000  82.000000  2709.0
# 5       A.C. Green  1991  27.0  58.000000  82.000000  21.000000  2164.0
# 6       A.C. Green  1992  28.0  43.000000  82.000000  53.000000  2902.0
# 7       A.C. Green  1993  29.0  39.000000  82.000000  55.000000  2819.0
# 8       A.C. Green  1994  30.0  56.000000  82.000000  55.000000  2825.0
# 9       A.C. Green  1995  31.0  59.000000  82.000000  52.000000  2687.0
# 10      A.C. Green  1996  32.0  41.000000  82.000000  36.000000  2113.0
# 11      A.C. Green  1997  33.0  32.000000  41.500000  36.500000  1246.0
# ...

# %%
abc.to_csv(r'C:\Users\kengw\Desktop\stats_1.4.csv')
